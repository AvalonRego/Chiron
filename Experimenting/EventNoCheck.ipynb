# %%
import os
import h5py
import multiprocessing
from tqdm import tqdm

directory = "/viper/ptmp/arego/LBC/"
column_to_check = "event_no"
datasets_to_check = ["/hits/table", "/records/table"]

def check_and_delete_hdf5(file_path):
    """Check if an HDF5 file has the required column in datasets, delete if missing."""
    logs = []  # Collect logs here instead of printing
    try:
        with h5py.File(file_path, "r") as f:
            for dataset in datasets_to_check:
                if dataset in f:
                    data = f[dataset]

                    if not isinstance(data, h5py.Dataset):  # Ensure it's a dataset
                        logs.append(f"Skipping {dataset} in {file_path}: Not a dataset")
                        continue  # Skip groups

                    logs.append(f"Checking {dataset} in {file_path}: {data.dtype.names}")  # Debug print

                    # ✅ FIX: Compare column names as strings
                    if column_to_check not in map(str, data.dtype.names):
                        logs.append(f"❌ Column '{column_to_check}' not found in {dataset}, deleting file.")
                        # os.remove(file_path)  # Uncomment when confident
                        return file_path, logs  # Return deleted file and logs

                else:
                    logs.append(f"❌ Dataset {dataset} missing in {file_path}, deleting file.")
                    # os.remove(file_path)  # Uncomment when confident
                    return file_path, logs

        logs.append(f"✅ File {file_path} is good")
        return None, logs  # File is valid

    except Exception as e:
        logs.append(f"❌ Error processing {file_path}: {e}")
        return None, logs

def process_files_parallel(files):
    """Process HDF5 files in parallel and print all logs at the end."""
    logs_collection = []
    
    with multiprocessing.Pool(processes=8) as pool:
        with tqdm(total=len(files), desc="Checking HDF5 Files") as pbar:
            for deleted_file, logs in pool.imap_unordered(check_and_delete_hdf5, files):
                logs_collection.extend(logs)
                if deleted_file:
                    logs_collection.append(f"🗑️ Deleted: {deleted_file}")
                pbar.update(1)

    # Print all logs at the end
    print("\n".join(logs_collection))

if __name__ == "__main__":
    hdf_files = [os.path.join(directory, f) for f in os.listdir(directory) if f.endswith(".h5")]

    if not hdf_files:
        print("No HDF5 files found.")
    else:
        print(f"🔍 Checking {len(hdf_files)} HDF5 files in parallel...")
        process_files_parallel(hdf_files)
        print("✅ Processing complete!")
# Out:
# 🔍 Checking 5381 HDF5 files in parallel...
# Checking HDF5 Files: 100%|██████████| 5381/5381 [01:10<00:00, 76.72it/s]
# Checking /hits/table in /viper/ptmp/arego/LBC/3635.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/3635.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/3635.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/5327.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/5327.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/5327.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/2295.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/2295.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/2295.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/2584.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/2584.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/2584.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/100.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/100.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/100.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/1151.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/1151.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/1151.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/822.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/822.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/822.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/5190.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/5190.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/5190.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/690.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/690.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/690.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/467.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/467.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/467.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/1943.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/1943.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/1943.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/1654.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/1654.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/1654.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/1286.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/1286.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/1286.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/3267.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/3267.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/3267.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/2202.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/2202.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/2202.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/4029.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/4029.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/4029.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/4318.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/4318.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/4318.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/4973.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/4973.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/4973.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/409.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/409.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/409.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/632.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/632.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/632.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/2337.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/2337.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/2337.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/83.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/83.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/83.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/2626.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/2626.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/2626.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/4181.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/4181.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/4181.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/2992.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/2992.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/2992.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/3251.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/3251.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/3251.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/5232.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/5232.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/5232.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/999.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/999.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/999.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/3540.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/3540.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/3540.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/1328.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/1328.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/1328.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/277.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/277.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/277.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/5367.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/5367.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/5367.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/442.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/442.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/442.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/942.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/942.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/942.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/2610.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/2610.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/2610.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/3675.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/3675.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/3675.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/3964.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/3964.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/3964.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/4223.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/4223.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/4223.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/4358.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/4358.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/4358.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/1191.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/1191.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/1191.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/1983.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/1983.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/1983.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/219.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/219.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/219.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/4726.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/4726.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/4726.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/2242.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/2242.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/2242.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/2377.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/2377.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/2377.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/1601.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/1601.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/1601.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/252.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/252.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/252.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/77.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/77.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/77.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/2666.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/2666.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/2666.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/3717.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/3717.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/3717.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/5272.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/5272.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/5272.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/1233.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/1233.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/1233.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/3580.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/3580.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/3580.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/3349.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/3349.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/3349.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/1736.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/1736.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/1736.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/1368.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/1368.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/1368.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/4920.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/4920.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/4920.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/4631.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/4631.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/4631.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/40.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/40.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/40.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/2571.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/2571.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/2571.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/2282.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/2282.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/2282.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/4263.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/4263.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/4263.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/4766.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/4766.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/4766.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/2708.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/2708.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/2708.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/2419.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/2419.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/2419.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/3333.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/3333.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/3333.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/5314.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/5314.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/5314.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/1930.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/1930.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/1930.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/4398.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/4398.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/4398.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/4808.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/4808.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/4808.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/3622.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/3622.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/3622.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/1641.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/1641.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/1641.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/3757.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/3757.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/3757.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/1273.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/1273.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/1273.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/3389.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/3389.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/3389.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/2324.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/2324.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/2324.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/4305.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/4305.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/4305.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/4016.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/4016.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/4016.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/3007.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/3007.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/3007.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/2748.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/2748.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/2748.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/4671.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/4671.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/4671.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/4960.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/4960.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/4960.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/1697.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/1697.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/1697.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/2459.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/2459.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/2459.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/1026.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/1026.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/1026.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/5354.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/5354.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/5354.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/1315.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/1315.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/1315.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/1818.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/1818.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/1818.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/3662.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/3662.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/3662.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/846.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/846.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/846.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/1970.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/1970.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/1970.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/3294.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/3294.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/3294.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/4345.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/4345.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/4345.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/1681.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/1681.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/1681.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/3797.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/3797.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/3797.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/4713.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/4713.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/4713.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/2364.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/2364.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/2364.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/3415.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/3415.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/3415.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/4848.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/4848.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/4848.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/4056.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/4056.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/4056.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/2653.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/2653.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/2653.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/2788.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/2788.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/2788.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/5028.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/5028.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/5028.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/656.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/656.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/656.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/1723.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/1723.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/1723.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/3704.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/3704.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/3704.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/2499.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/2499.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/2499.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/1858.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/1858.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/1858.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/3047.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/3047.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/3047.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/821.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/821.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/821.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/1066.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/1066.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/1066.h5 is good
# Checking /hits/table in /viper/ptmp/arego/LBC/4753.h5: ('index', 'time', 'record_id', 'string_id', 'module_id', 'pmt_id', 'event_no')
# Checking /records/table in /viper/ptmp/arego/LBC/4753.h5: ('index', 'record_id', 'time', 'duration', 'location_x', 'location_y', 'location_z', 'orientation_x', 'orientation_y', 'orientation_z', 'energy', 'particle_id', 'length', 'event_no', 'type')
# ✅ File /viper/ptmp/arego/LBC/4753.h5 is good
# ...
# ❌ Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/2173.h5
# Checking /hits/table in /viper/ptmp/arego/LBC/5205.h5: ('index', 'time', 'record_id', 'type', 'string_id', 'module_id', 'pmt_id')
# ❌ Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/5205.h5
# Checking /hits/table in /viper/ptmp/arego/LBC/4578.h5: ('index', 'time', 'record_id', 'type', 'string_id', 'module_id', 'pmt_id')
# ❌ Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/4578.h5
# Checking /hits/table in /viper/ptmp/arego/LBC/4289.h5: ('index', 'time', 'record_id', 'type', 'string_id', 'module_id', 'pmt_id')
# ❌ Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/4289.h5
# Checking /hits/table in /viper/ptmp/arego/LBC/1532.h5: ('index', 'time', 'record_id', 'type', 'string_id', 'module_id', 'pmt_id')
# ❌ Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/1532.h5
# Checking /hits/table in /viper/ptmp/arego/LBC/2965.h5: ('index', 'time', 'record_id', 'type', 'string_id', 'module_id', 'pmt_id')
# ❌ Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/2965.h5
# Checking /hits/table in /viper/ptmp/arego/LBC/3513.h5: ('index', 'time', 'record_id', 'type', 'string_id', 'module_id', 'pmt_id')
# ❌ Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/3513.h5
# Checking /hits/table in /viper/ptmp/arego/LBC/3145.h5: ('index', 'time', 'record_id', 'type', 'string_id', 'module_id', 'pmt_id')
# ❌ Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/3145.h5
# Checking /hits/table in /viper/ptmp/arego/LBC/1821.h5: ('index', 'time', 'record_id', 'type', 'string_id', 'module_id', 'pmt_id')
# ❌ Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/1821.h5
# Checking /hits/table in /viper/ptmp/arego/LBC/3648.h5: ('index', 'time', 'record_id', 'type', 'string_id', 'module_id', 'pmt_id')
# ❌ Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/3648.h5
# Checking /hits/table in /viper/ptmp/arego/LBC/2597.h5: ('index', 'time', 'record_id', 'type', 'string_id', 'module_id', 'pmt_id')
# ❌ Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/2597.h5
# Checking /hits/table in /viper/ptmp/arego/LBC/3937.h5: ('index', 'time', 'record_id', 'type', 'string_id', 'module_id', 'pmt_id')
# ❌ Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/3937.h5
# Checking /hits/table in /viper/ptmp/arego/LBC/2215.h5: ('index', 'time', 'record_id', 'type', 'string_id', 'module_id', 'pmt_id')
# ❌ Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/2215.h5
# Checking /hits/table in /viper/ptmp/arego/LBC/1956.h5: ('index', 'time', 'record_id', 'type', 'string_id', 'module_id', 'pmt_id')
# ❌ Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/1956.h5
# Checking /hits/table in /viper/ptmp/arego/LBC/2504.h5: ('index', 'time', 'record_id', 'type', 'string_id', 'module_id', 'pmt_id')
# ❌ Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/2504.h5
# Checking /hits/table in /viper/ptmp/arego/LBC/4562.h5: ('index', 'time', 'record_id', 'type', 'string_id', 'module_id', 'pmt_id')
# ❌ Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/4562.h5
# Checking /hits/table in /viper/ptmp/arego/LBC/1299.h5: ('index', 'time', 'record_id', 'type', 'string_id', 'module_id', 'pmt_id')
# ❌ Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/1299.h5
# Checking /hits/table in /viper/ptmp/arego/LBC/1164.h5: ('index', 'time', 'record_id', 'type', 'string_id', 'module_id', 'pmt_id')
# ❌ Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/1164.h5
# Checking /hits/table in /viper/ptmp/arego/LBC/2639.h5: ('index', 'time', 'record_id', 'type', 'string_id', 'module_id', 'pmt_id')
# ❌ Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/2639.h5
# Checking /hits/table in /viper/ptmp/arego/LBC/4851.h5: ('index', 'time', 'record_id', 'type', 'string_id', 'module_id', 'pmt_id')
# ❌ Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/4851.h5
# Checking /hits/table in /viper/ptmp/arego/LBC/5110.h5: ('index', 'time', 'record_id', 'type', 'string_id', 'module_id', 'pmt_id')
# ❌ Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/5110.h5
# Checking /hits/table in /viper/ptmp/arego/LBC/4986.h5: ('index', 'time', 'record_id', 'type', 'string_id', 'module_id', 'pmt_id')
# ❌ Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/4986.h5
# Checking /hits/table in /viper/ptmp/arego/LBC/4194.h5: ('index', 'time', 'record_id', 'type', 'string_id', 'module_id', 'pmt_id')
# ❌ Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/4194.h5
# Checking /hits/table in /viper/ptmp/arego/LBC/1588.h5: ('index', 'time', 'record_id', 'type', 'string_id', 'module_id', 'pmt_id')
# ❌ Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/1588.h5
# Checking /hits/table in /viper/ptmp/arego/LBC/2870.h5: ('index', 'time', 'record_id', 'type', 'string_id', 'module_id', 'pmt_id')
# ❌ Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/2870.h5
# Checking /hits/table in /viper/ptmp/arego/LBC/5245.h5: ('index', 'time', 'record_id', 'type', 'string_id', 'module_id', 'pmt_id')
# ❌ Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/5245.h5
# Checking /hits/table in /viper/ptmp/arego/LBC/3553.h5: ('index', 'time', 'record_id', 'type', 'string_id', 'module_id', 'pmt_id')
# ❌ Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/3553.h5
# Checking /hits/table in /viper/ptmp/arego/LBC/1206.h5: ('index', 'time', 'record_id', 'type', 'string_id', 'module_id', 'pmt_id')
# ❌ Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/1206.h5
# Checking /hits/table in /viper/ptmp/arego/LBC/1709.h5: ('index', 'time', 'record_id', 'type', 'string_id', 'module_id', 'pmt_id')
# ❌ Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/1709.h5
# Checking /hits/table in /viper/ptmp/arego/LBC/3185.h5: ('index', 'time', 'record_id', 'type', 'string_id', 'module_id', 'pmt_id')
# ❌ Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/3185.h5
# Checking /hits/table in /viper/ptmp/arego/LBC/3921.h5: ('index', 'time', 'record_id', 'type', 'string_id', 'module_id', 'pmt_id')
# ❌ Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/3921.h5
# Checking /hits/table in /viper/ptmp/arego/LBC/537.h5: ('index', 'time', 'record_id', 'type', 'string_id', 'module_id', 'pmt_id')
# ❌ Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/537.h5
# Checking /hits/table in /viper/ptmp/arego/LBC/4101.h5: ('index', 'time', 'record_id', 'type', 'string_id', 'module_id', 'pmt_id')
# ❌ Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/4101.h5
# Checking /hits/table in /viper/ptmp/arego/LBC/3688.h5: ('index', 'time', 'record_id', 'type', 'string_id', 'module_id', 'pmt_id')
# ❌ Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/3688.h5
# Checking /hits/table in /viper/ptmp/arego/LBC/4604.h5: ('index', 'time', 'record_id', 'type', 'string_id', 'module_id', 'pmt_id')
# ❌ Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/4604.h5
# Checking /hits/table in /viper/ptmp/arego/LBC/1861.h5: ('index', 'time', 'record_id', 'type', 'string_id', 'module_id', 'pmt_id')
# ❌ Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/1861.h5
# Checking /hits/table in /viper/ptmp/arego/LBC/1493.h5: ('index', 'time', 'record_id', 'type', 'string_id', 'module_id', 'pmt_id')
# ❌ Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/1493.h5
# Checking /hits/table in /viper/ptmp/arego/LBC/3977.h5: ('index', 'time', 'record_id', 'type', 'string_id', 'module_id', 'pmt_id')
# ❌ Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/3977.h5
# Checking /hits/table in /viper/ptmp/arego/LBC/2912.h5: ('index', 'time', 'record_id', 'type', 'string_id', 'module_id', 'pmt_id')
# ❌ Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/2912.h5
# Checking /hits/table in /viper/ptmp/arego/LBC/4236.h5: ('index', 'time', 'record_id', 'type', 'string_id', 'module_id', 'pmt_id')
# ❌ Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/4236.h5
# Checking /hits/table in /viper/ptmp/arego/LBC/2120.h5: ('index', 'time', 'record_id', 'type', 'string_id', 'module_id', 'pmt_id')
# ❌ Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/2120.h5
# Checking /hits/table in /viper/ptmp/arego/LBC/1996.h5: ('index', 'time', 'record_id', 'type', 'string_id', 'module_id', 'pmt_id')
# ❌ Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/1996.h5
# Checking /hits/table in /viper/ptmp/arego/LBC/2544.h5: ('index', 'time', 'record_id', 'type', 'string_id', 'module_id', 'pmt_id')
# ❌ Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/2544.h5
# Checking /hits/table in /viper/ptmp/arego/LBC/4891.h5: ('index', 'time', 'record_id', 'type', 'string_id', 'module_id', 'pmt_id')
# ❌ Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/4891.h5
# Checking /hits/table in /viper/ptmp/arego/LBC/5150.h5: ('index', 'time', 'record_id', 'type', 'string_id', 'module_id', 'pmt_id')
# ❌ Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/5150.h5
# Checking /hits/table in /viper/ptmp/arego/LBC/2255.h5: ('index', 'time', 'record_id', 'type', 'string_id', 'module_id', 'pmt_id')
# ❌ Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/2255.h5
# Checking /hits/table in /viper/ptmp/arego/LBC/847.h5: ('index', 'time', 'record_id', 'type', 'string_id', 'module_id', 'pmt_id')
# ❌ Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/847.h5
# Checking /hits/table in /viper/ptmp/arego/LBC/1111.h5: ('index', 'time', 'record_id', 'type', 'string_id', 'module_id', 'pmt_id')
# ❌ Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/1111.h5
# Checking /hits/table in /viper/ptmp/arego/LBC/2679.h5: ('index', 'time', 'record_id', 'type', 'string_id', 'module_id', 'pmt_id')
# ❌ Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/2679.h5
# Checking /hits/table in /viper/ptmp/arego/LBC/3227.h5: ('index', 'time', 'record_id', 'type', 'string_id', 'module_id', 'pmt_id')
# ❌ Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/3227.h5
# Checking /hits/table in /viper/ptmp/arego/LBC/347.h5: ('index', 'time', 'record_id', 'type', 'string_id', 'module_id', 'pmt_id')
# ❌ Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/347.h5
# Checking /hits/table in /viper/ptmp/arego/LBC/1614.h5: ('index', 'time', 'record_id', 'type', 'string_id', 'module_id', 'pmt_id')
# ❌ Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/1614.h5
# Checking /hits/table in /viper/ptmp/arego/LBC/1903.h5: ('index', 'time', 'record_id', 'type', 'string_id', 'module_id', 'pmt_id')
# ❌ Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/1903.h5
# Checking /hits/table in /viper/ptmp/arego/LBC/5285.h5: ('index', 'time', 'record_id', 'type', 'string_id', 'module_id', 'pmt_id')
# ❌ Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/5285.h5
# Checking /hits/table in /viper/ptmp/arego/LBC/3090.h5: ('index', 'time', 'record_id', 'type', 'string_id', 'module_id', 'pmt_id')
# ❌ Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/3090.h5
# Checking /hits/table in /viper/ptmp/arego/LBC/880.h5: ('index', 'time', 'record_id', 'type', 'string_id', 'module_id', 'pmt_id')
# ❌ Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/880.h5
# Checking /hits/table in /viper/ptmp/arego/LBC/1246.h5: ('index', 'time', 'record_id', 'type', 'string_id', 'module_id', 'pmt_id')
# ❌ Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/1246.h5
# Checking /hits/table in /viper/ptmp/arego/LBC/4141.h5: ('index', 'time', 'record_id', 'type', 'string_id', 'module_id', 'pmt_id')
# ❌ Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/4141.h5
# Checking /hits/table in /viper/ptmp/arego/LBC/3593.h5: ('index', 'time', 'record_id', 'type', 'string_id', 'module_id', 'pmt_id')
# ❌ Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/3593.h5
# Checking /hits/table in /viper/ptmp/arego/LBC/3882.h5: ('index', 'time', 'record_id', 'type', 'string_id', 'module_id', 'pmt_id')
# ❌ Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/3882.h5
# Checking /hits/table in /viper/ptmp/arego/LBC/4644.h5: ('index', 'time', 'record_id', 'type', 'string_id', 'module_id', 'pmt_id')
# ❌ Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/4644.h5
# Checking /hits/table in /viper/ptmp/arego/LBC/2160.h5: ('index', 'time', 'record_id', 'type', 'string_id', 'module_id', 'pmt_id')
# ❌ Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/2160.h5
# Checking /hits/table in /viper/ptmp/arego/LBC/4933.h5: ('index', 'time', 'record_id', 'type', 'string_id', 'module_id', 'pmt_id')
# ❌ Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/4933.h5
# Checking /hits/table in /viper/ptmp/arego/LBC/157.h5: ('index', 'time', 'record_id', 'type', 'string_id', 'module_id', 'pmt_id')
# ❌ Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/157.h5
# Checking /hits/table in /viper/ptmp/arego/LBC/657.h5: ('index', 'time', 'record_id', 'type', 'string_id', 'module_id', 'pmt_id')
# ❌ Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/657.h5
# Checking /hits/table in /viper/ptmp/arego/LBC/4276.h5: ('index', 'time', 'record_id', 'type', 'string_id', 'module_id', 'pmt_id')
# ❌ Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/4276.h5
# Checking /hits/table in /viper/ptmp/arego/LBC/3211.h5: ('index', 'time', 'record_id', 'type', 'string_id', 'module_id', 'pmt_id')
# ❌ Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/3211.h5
# Checking /hits/table in /viper/ptmp/arego/LBC/3500.h5: ('index', 'time', 'record_id', 'type', 'string_id', 'module_id', 'pmt_id')
# ❌ Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/3500.h5
# Checking /hits/table in /viper/ptmp/arego/LBC/2952.h5: ('index', 'time', 'record_id', 'type', 'string_id', 'module_id', 'pmt_id')
# ❌ Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/2952.h5
# ✅ Processing complete!

# %%
len([os.path.join(directory, f) for f in os.listdir(directory) if f.endswith(".h5")])
# Out:
# 2833

# %%
import os
import h5py
import multiprocessing
from tqdm import tqdm

directory = "/viper/ptmp/arego/LBC/"
column_to_check = "event_no"
datasets_to_check = ["/hits/table", "/records/table"]

def check_and_delete_hdf5(file_path):
    """Check if an HDF5 file has the required column in datasets, delete if missing."""
    logs = []  # Collect logs here instead of printing
    try:
        with h5py.File(file_path, "r") as f:
            for dataset in datasets_to_check:
                if dataset in f:
                    data = f[dataset]

                    if not isinstance(data, h5py.Dataset):  # Ensure it's a dataset
                        logs.append(f"Skipping {dataset} in {file_path}: Not a dataset")
                        continue  # Skip groups

                    # ✅ FIX: Compare column names as strings
                    if column_to_check not in map(str, data.dtype.names):
                        logs.append(f"Column '{column_to_check}' not found in {dataset}, deleting file.")
                        os.remove(file_path)  # Uncomment when confident
                        return file_path, logs, False  # File deleted

                else:
                    logs.append(f"Dataset {dataset} missing in {file_path}, deleting file.")
                    os.remove(file_path)  # Uncomment when confident
                    return file_path, logs, False  # File deleted

        logs.append(f"File {file_path} is good")
        return None, logs, True  # File kept

    except Exception as e:
        logs.append(f"Error processing {file_path}: {e}")
        return None, logs, True  # Assume file is kept to avoid miscount

def process_files_parallel(files):
    """Process HDF5 files in parallel and print all logs at the end."""
    logs_collection = []
    deleted_count = 0
    kept_count = 0
    
    with multiprocessing.Pool(processes=8) as pool:
        with tqdm(total=len(files), desc="Checking HDF5 Files") as pbar:
            for deleted_file, logs, kept in pool.imap_unordered(check_and_delete_hdf5, files):
                logs_collection.extend(logs)
                if deleted_file:
                    logs_collection.append(f"🗑️ Deleted: {deleted_file}")
                    deleted_count += 1
                else:
                    kept_count += 1
                pbar.update(1)

    # Print all logs at the end
    print("\n".join(logs_collection))
    print(f"\n✅ Summary: {deleted_count} files deleted, {kept_count} files kept.")

if __name__ == "__main__":
    hdf_files = [os.path.join(directory, f) for f in os.listdir(directory) if f.endswith(".h5")]

    if not hdf_files:
        print("No HDF5 files found.")
    else:
        print(f"🔍 Checking {len(hdf_files)} HDF5 files in parallel...")
        process_files_parallel(hdf_files)
        print("✅ Processing complete!")
# Out:
# 🔍 Checking 5381 HDF5 files in parallel...
# Checking HDF5 Files: 100%|██████████| 5381/5381 [00:55<00:00, 97.46it/s]
# File /viper/ptmp/arego/LBC/3635.h5 is good
# File /viper/ptmp/arego/LBC/1151.h5 is good
# File /viper/ptmp/arego/LBC/100.h5 is good
# File /viper/ptmp/arego/LBC/822.h5 is good
# File /viper/ptmp/arego/LBC/5190.h5 is good
# File /viper/ptmp/arego/LBC/5327.h5 is good
# File /viper/ptmp/arego/LBC/2295.h5 is good
# File /viper/ptmp/arego/LBC/2584.h5 is good
# File /viper/ptmp/arego/LBC/1654.h5 is good
# File /viper/ptmp/arego/LBC/690.h5 is good
# File /viper/ptmp/arego/LBC/1286.h5 is good
# File /viper/ptmp/arego/LBC/4029.h5 is good
# File /viper/ptmp/arego/LBC/1943.h5 is good
# File /viper/ptmp/arego/LBC/632.h5 is good
# File /viper/ptmp/arego/LBC/409.h5 is good
# File /viper/ptmp/arego/LBC/3267.h5 is good
# File /viper/ptmp/arego/LBC/467.h5 is good
# File /viper/ptmp/arego/LBC/2202.h5 is good
# File /viper/ptmp/arego/LBC/4318.h5 is good
# File /viper/ptmp/arego/LBC/2337.h5 is good
# File /viper/ptmp/arego/LBC/2992.h5 is good
# File /viper/ptmp/arego/LBC/4181.h5 is good
# File /viper/ptmp/arego/LBC/3251.h5 is good
# File /viper/ptmp/arego/LBC/999.h5 is good
# File /viper/ptmp/arego/LBC/4973.h5 is good
# File /viper/ptmp/arego/LBC/2626.h5 is good
# File /viper/ptmp/arego/LBC/83.h5 is good
# File /viper/ptmp/arego/LBC/5232.h5 is good
# File /viper/ptmp/arego/LBC/5367.h5 is good
# File /viper/ptmp/arego/LBC/442.h5 is good
# File /viper/ptmp/arego/LBC/3964.h5 is good
# File /viper/ptmp/arego/LBC/1191.h5 is good
# File /viper/ptmp/arego/LBC/3540.h5 is good
# File /viper/ptmp/arego/LBC/277.h5 is good
# File /viper/ptmp/arego/LBC/1328.h5 is good
# File /viper/ptmp/arego/LBC/3675.h5 is good
# File /viper/ptmp/arego/LBC/942.h5 is good
# File /viper/ptmp/arego/LBC/2610.h5 is good
# File /viper/ptmp/arego/LBC/4223.h5 is good
# File /viper/ptmp/arego/LBC/4358.h5 is good
# File /viper/ptmp/arego/LBC/2377.h5 is good
# File /viper/ptmp/arego/LBC/219.h5 is good
# File /viper/ptmp/arego/LBC/4726.h5 is good
# File /viper/ptmp/arego/LBC/252.h5 is good
# File /viper/ptmp/arego/LBC/1983.h5 is good
# File /viper/ptmp/arego/LBC/2242.h5 is good
# File /viper/ptmp/arego/LBC/3717.h5 is good
# File /viper/ptmp/arego/LBC/2666.h5 is good
# File /viper/ptmp/arego/LBC/1601.h5 is good
# File /viper/ptmp/arego/LBC/5272.h5 is good
# File /viper/ptmp/arego/LBC/77.h5 is good
# File /viper/ptmp/arego/LBC/3580.h5 is good
# File /viper/ptmp/arego/LBC/1233.h5 is good
# File /viper/ptmp/arego/LBC/3349.h5 is good
# File /viper/ptmp/arego/LBC/4631.h5 is good
# File /viper/ptmp/arego/LBC/1368.h5 is good
# File /viper/ptmp/arego/LBC/1736.h5 is good
# File /viper/ptmp/arego/LBC/2419.h5 is good
# File /viper/ptmp/arego/LBC/4920.h5 is good
# File /viper/ptmp/arego/LBC/40.h5 is good
# File /viper/ptmp/arego/LBC/2282.h5 is good
# File /viper/ptmp/arego/LBC/2571.h5 is good
# File /viper/ptmp/arego/LBC/4766.h5 is good
# File /viper/ptmp/arego/LBC/4398.h5 is good
# File /viper/ptmp/arego/LBC/2708.h5 is good
# File /viper/ptmp/arego/LBC/4263.h5 is good
# File /viper/ptmp/arego/LBC/3333.h5 is good
# File /viper/ptmp/arego/LBC/1930.h5 is good
# File /viper/ptmp/arego/LBC/3757.h5 is good
# File /viper/ptmp/arego/LBC/5314.h5 is good
# File /viper/ptmp/arego/LBC/1641.h5 is good
# File /viper/ptmp/arego/LBC/4808.h5 is good
# File /viper/ptmp/arego/LBC/3622.h5 is good
# File /viper/ptmp/arego/LBC/3389.h5 is good
# File /viper/ptmp/arego/LBC/1273.h5 is good
# File /viper/ptmp/arego/LBC/4016.h5 is good
# File /viper/ptmp/arego/LBC/4305.h5 is good
# File /viper/ptmp/arego/LBC/2324.h5 is good
# File /viper/ptmp/arego/LBC/3007.h5 is good
# File /viper/ptmp/arego/LBC/5354.h5 is good
# File /viper/ptmp/arego/LBC/1697.h5 is good
# File /viper/ptmp/arego/LBC/4671.h5 is good
# File /viper/ptmp/arego/LBC/1026.h5 is good
# File /viper/ptmp/arego/LBC/4960.h5 is good
# File /viper/ptmp/arego/LBC/2459.h5 is good
# File /viper/ptmp/arego/LBC/3294.h5 is good
# File /viper/ptmp/arego/LBC/2748.h5 is good
# File /viper/ptmp/arego/LBC/1315.h5 is good
# File /viper/ptmp/arego/LBC/846.h5 is good
# File /viper/ptmp/arego/LBC/4713.h5 is good
# File /viper/ptmp/arego/LBC/1970.h5 is good
# File /viper/ptmp/arego/LBC/4345.h5 is good
# File /viper/ptmp/arego/LBC/1818.h5 is good
# File /viper/ptmp/arego/LBC/3797.h5 is good
# File /viper/ptmp/arego/LBC/1681.h5 is good
# File /viper/ptmp/arego/LBC/3662.h5 is good
# File /viper/ptmp/arego/LBC/2364.h5 is good
# File /viper/ptmp/arego/LBC/5028.h5 is good
# File /viper/ptmp/arego/LBC/2653.h5 is good
# File /viper/ptmp/arego/LBC/3415.h5 is good
# File /viper/ptmp/arego/LBC/4848.h5 is good
# File /viper/ptmp/arego/LBC/4056.h5 is good
# File /viper/ptmp/arego/LBC/656.h5 is good
# File /viper/ptmp/arego/LBC/2788.h5 is good
# File /viper/ptmp/arego/LBC/3704.h5 is good
# File /viper/ptmp/arego/LBC/1723.h5 is good
# File /viper/ptmp/arego/LBC/1858.h5 is good
# File /viper/ptmp/arego/LBC/3839.h5 is good
# File /viper/ptmp/arego/LBC/2499.h5 is good
# File /viper/ptmp/arego/LBC/1355.h5 is good
# File /viper/ptmp/arego/LBC/3047.h5 is good
# File /viper/ptmp/arego/LBC/4250.h5 is good
# File /viper/ptmp/arego/LBC/2406.h5 is good
# File /viper/ptmp/arego/LBC/821.h5 is good
# File /viper/ptmp/arego/LBC/4753.h5 is good
# File /viper/ptmp/arego/LBC/5012.h5 is good
# File /viper/ptmp/arego/LBC/5301.h5 is good
# File /viper/ptmp/arego/LBC/466.h5 is good
# File /viper/ptmp/arego/LBC/1066.h5 is good
# File /viper/ptmp/arego/LBC/4385.h5 is good
# File /viper/ptmp/arego/LBC/3320.h5 is good
# File /viper/ptmp/arego/LBC/2038.h5 is good
# File /viper/ptmp/arego/LBC/4096.h5 is good
# File /viper/ptmp/arego/LBC/1108.h5 is good
# File /viper/ptmp/arego/LBC/408.h5 is good
# File /viper/ptmp/arego/LBC/631.h5 is good
# File /viper/ptmp/arego/LBC/1260.h5 is good
# File /viper/ptmp/arego/LBC/5068.h5 is good
# File /viper/ptmp/arego/LBC/2693.h5 is good
# File /viper/ptmp/arego/LBC/3744.h5 is good
# File /viper/ptmp/arego/LBC/3087.h5 is good
# File /viper/ptmp/arego/LBC/4003.h5 is good
# File /viper/ptmp/arego/LBC/3455.h5 is good
# File /viper/ptmp/arego/LBC/276.h5 is good
# File /viper/ptmp/arego/LBC/998.h5 is good
# File /viper/ptmp/arego/LBC/3879.h5 is good
# File /viper/ptmp/arego/LBC/1763.h5 is good
# File /viper/ptmp/arego/LBC/2022.h5 is good
# File /viper/ptmp/arego/LBC/2311.h5 is good
# File /viper/ptmp/arego/LBC/1395.h5 is good
# File /viper/ptmp/arego/LBC/4427.h5 is good
# File /viper/ptmp/arego/LBC/2446.h5 is good
# File /viper/ptmp/arego/LBC/4138.h5 is good
# File /viper/ptmp/arego/LBC/4290.h5 is good
# File /viper/ptmp/arego/LBC/218.h5 is good
# File /viper/ptmp/arego/LBC/441.h5 is good
# File /viper/ptmp/arego/LBC/3129.h5 is good
# File /viper/ptmp/arego/LBC/2814.h5 is good
# File /viper/ptmp/arego/LBC/941.h5 is good
# File /viper/ptmp/arego/LBC/1013.h5 is good
# File /viper/ptmp/arego/LBC/4793.h5 is good
# File /viper/ptmp/arego/LBC/2078.h5 is good
# File /viper/ptmp/arego/LBC/3360.h5 is good
# File /viper/ptmp/arego/LBC/1437.h5 is good
# File /viper/ptmp/arego/LBC/5341.h5 is good
# File /viper/ptmp/arego/LBC/1805.h5 is good
# File /viper/ptmp/arego/LBC/1148.h5 is good
# File /viper/ptmp/arego/LBC/751.h5 is good
# File /viper/ptmp/arego/LBC/4043.h5 is good
# File /viper/ptmp/arego/LBC/4700.h5 is good
# File /viper/ptmp/arego/LBC/251.h5 is good
# File /viper/ptmp/arego/LBC/3784.h5 is good
# File /viper/ptmp/arego/LBC/4178.h5 is good
# File /viper/ptmp/arego/LBC/2775.h5 is good
# File /viper/ptmp/arego/LBC/4332.h5 is good
# File /viper/ptmp/arego/LBC/3402.h5 is good
# File /viper/ptmp/arego/LBC/3034.h5 is good
# File /viper/ptmp/arego/LBC/2351.h5 is good
# File /viper/ptmp/arego/LBC/2486.h5 is good
# File /viper/ptmp/arego/LBC/4467.h5 is good
# File /viper/ptmp/arego/LBC/82.h5 is good
# File /viper/ptmp/arego/LBC/3537.h5 is good
# File /viper/ptmp/arego/LBC/1053.h5 is good
# File /viper/ptmp/arego/LBC/4835.h5 is good
# File /viper/ptmp/arego/LBC/3826.h5 is good
# File /viper/ptmp/arego/LBC/1845.h5 is good
# File /viper/ptmp/arego/LBC/561.h5 is good
# File /viper/ptmp/arego/LBC/1710.h5 is good
# File /viper/ptmp/arego/LBC/1342.h5 is good
# File /viper/ptmp/arego/LBC/3169.h5 is good
# File /viper/ptmp/arego/LBC/4083.h5 is good
# File /viper/ptmp/arego/LBC/4509.h5 is good
# File /viper/ptmp/arego/LBC/4740.h5 is good
# File /viper/ptmp/arego/LBC/1188.h5 is good
# File /viper/ptmp/arego/LBC/1477.h5 is good
# File /viper/ptmp/arego/LBC/2104.h5 is good
# File /viper/ptmp/arego/LBC/503.h5 is good
# File /viper/ptmp/arego/LBC/4875.h5 is good
# File /viper/ptmp/arego/LBC/2391.h5 is good
# File /viper/ptmp/arego/LBC/4372.h5 is good
# File /viper/ptmp/arego/LBC/2528.h5 is good
# File /viper/ptmp/arego/LBC/5134.h5 is good
# File /viper/ptmp/arego/LBC/313.h5 is good
# File /viper/ptmp/arego/LBC/371.h5 is good
# File /viper/ptmp/arego/LBC/3442.h5 is good
# File /viper/ptmp/arego/LBC/3866.h5 is good
# File /viper/ptmp/arego/LBC/1519.h5 is good
# File /viper/ptmp/arego/LBC/3731.h5 is good
# File /viper/ptmp/arego/LBC/1382.h5 is good
# File /viper/ptmp/arego/LBC/1093.h5 is good
# File /viper/ptmp/arego/LBC/181.h5 is good
# File /viper/ptmp/arego/LBC/3074.h5 is good
# File /viper/ptmp/arego/LBC/2801.h5 is good
# File /viper/ptmp/arego/LBC/1750.h5 is good
# File /viper/ptmp/arego/LBC/4917.h5 is good
# File /viper/ptmp/arego/LBC/76.h5 is good
# File /viper/ptmp/arego/LBC/1885.h5 is good
# File /viper/ptmp/arego/LBC/3498.h5 is good
# File /viper/ptmp/arego/LBC/4125.h5 is good
# File /viper/ptmp/arego/LBC/4780.h5 is good
# File /viper/ptmp/arego/LBC/4549.h5 is good
# File /viper/ptmp/arego/LBC/2433.h5 is good
# File /viper/ptmp/arego/LBC/2857.h5 is good
# File /viper/ptmp/arego/LBC/1000.h5 is good
# File /viper/ptmp/arego/LBC/845.h5 is good
# File /viper/ptmp/arego/LBC/2568.h5 is good
# File /viper/ptmp/arego/LBC/2065.h5 is good
# File /viper/ptmp/arego/LBC/3116.h5 is good
# File /viper/ptmp/arego/LBC/3482.h5 is good
# File /viper/ptmp/arego/LBC/3908.h5 is good
# File /viper/ptmp/arego/LBC/3619.h5 is good
# File /viper/ptmp/arego/LBC/1424.h5 is good
# File /viper/ptmp/arego/LBC/1135.h5 is good
# File /viper/ptmp/arego/LBC/1927.h5 is good
# File /viper/ptmp/arego/LBC/1559.h5 is good
# File /viper/ptmp/arego/LBC/5095.h5 is good
# File /viper/ptmp/arego/LBC/655.h5 is good
# File /viper/ptmp/arego/LBC/4165.h5 is good
# File /viper/ptmp/arego/LBC/4822.h5 is good
# File /viper/ptmp/arego/LBC/4030.h5 is good
# File /viper/ptmp/arego/LBC/3771.h5 is good
# File /viper/ptmp/arego/LBC/2841.h5 is good
# File /viper/ptmp/arego/LBC/820.h5 is good
# File /viper/ptmp/arego/LBC/4957.h5 is good
# File /viper/ptmp/arego/LBC/1790.h5 is good
# File /viper/ptmp/arego/LBC/2473.h5 is good
# File /viper/ptmp/arego/LBC/3813.h5 is good
# File /viper/ptmp/arego/LBC/4454.h5 is good
# File /viper/ptmp/arego/LBC/3021.h5 is good
# File /viper/ptmp/arego/LBC/4589.h5 is good
# File /viper/ptmp/arego/LBC/3524.h5 is good
# File /viper/ptmp/arego/LBC/3156.h5 is good
# File /viper/ptmp/arego/LBC/630.h5 is good
# File /viper/ptmp/arego/LBC/33.h5 is good
# File /viper/ptmp/arego/LBC/1832.h5 is good
# File /viper/ptmp/arego/LBC/5216.h5 is good
# File /viper/ptmp/arego/LBC/2897.h5 is good
# File /viper/ptmp/arego/LBC/1040.h5 is good
# File /viper/ptmp/arego/LBC/465.h5 is good
# File /viper/ptmp/arego/LBC/1464.h5 is good
# File /viper/ptmp/arego/LBC/4207.h5 is good
# File /viper/ptmp/arego/LBC/1967.h5 is good
# File /viper/ptmp/arego/LBC/3948.h5 is good
# File /viper/ptmp/arego/LBC/2515.h5 is good
# File /viper/ptmp/arego/LBC/1175.h5 is good
# File /viper/ptmp/arego/LBC/1599.h5 is good
# File /viper/ptmp/arego/LBC/407.h5 is good
# File /viper/ptmp/arego/LBC/4494.h5 is good
# File /viper/ptmp/arego/LBC/275.h5 is good
# File /viper/ptmp/arego/LBC/4070.h5 is good
# File /viper/ptmp/arego/LBC/4862.h5 is good
# File /viper/ptmp/arego/LBC/4997.h5 is good
# File /viper/ptmp/arego/LBC/5121.h5 is good
# File /viper/ptmp/arego/LBC/217.h5 is good
# File /viper/ptmp/arego/LBC/2226.h5 is good
# File /viper/ptmp/arego/LBC/940.h5 is good
# File /viper/ptmp/arego/LBC/3061.h5 is good
# File /viper/ptmp/arego/LBC/2939.h5 is good
# File /viper/ptmp/arego/LBC/1080.h5 is good
# File /viper/ptmp/arego/LBC/440.h5 is good
# File /viper/ptmp/arego/LBC/1872.h5 is good
# File /viper/ptmp/arego/LBC/3196.h5 is good
# File /viper/ptmp/arego/LBC/5177.h5 is good
# File /viper/ptmp/arego/LBC/3564.h5 is good
# File /viper/ptmp/arego/LBC/3853.h5 is good
# File /viper/ptmp/arego/LBC/1217.h5 is good
# File /viper/ptmp/arego/LBC/4904.h5 is good
# File /viper/ptmp/arego/LBC/4112.h5 is good
# File /viper/ptmp/arego/LBC/2131.h5 is good
# File /viper/ptmp/arego/LBC/3988.h5 is good
# File /viper/ptmp/arego/LBC/250.h5 is good
# File /viper/ptmp/arego/LBC/2420.h5 is good
# File /viper/ptmp/arego/LBC/2923.h5 is good
# File /viper/ptmp/arego/LBC/2555.h5 is good
# File /viper/ptmp/arego/LBC/4247.h5 is good
# File /viper/ptmp/arego/LBC/750.h5 is good
# File /viper/ptmp/arego/LBC/4536.h5 is good
# File /viper/ptmp/arego/LBC/5.h5 is good
# File /viper/ptmp/arego/LBC/3606.h5 is good
# File /viper/ptmp/arego/LBC/1122.h5 is good
# File /viper/ptmp/arego/LBC/3238.h5 is good
# File /viper/ptmp/arego/LBC/5161.h5 is good
# File /viper/ptmp/arego/LBC/2187.h5 is good
# File /viper/ptmp/arego/LBC/2979.h5 is good
# File /viper/ptmp/arego/LBC/1914.h5 is good
# File /viper/ptmp/arego/LBC/1546.h5 is good
# File /viper/ptmp/arego/LBC/1257.h5 is good
# File /viper/ptmp/arego/LBC/3893.h5 is good
# File /viper/ptmp/arego/LBC/2308.h5 is good
# File /viper/ptmp/arego/LBC/4520.h5 is good
# File /viper/ptmp/arego/LBC/560.h5 is good
# File /viper/ptmp/arego/LBC/4944.h5 is good
# File /viper/ptmp/arego/LBC/4152.h5 is good
# File /viper/ptmp/arego/LBC/2460.h5 is good
# File /viper/ptmp/arego/LBC/5203.h5 is good
# File /viper/ptmp/arego/LBC/502.h5 is good
# File /viper/ptmp/arego/LBC/4287.h5 is good
# File /viper/ptmp/arego/LBC/3511.h5 is good
# File /viper/ptmp/arego/LBC/2595.h5 is good
# File /viper/ptmp/arego/LBC/2171.h5 is good
# File /viper/ptmp/arego/LBC/3143.h5 is good
# File /viper/ptmp/arego/LBC/4576.h5 is good
# File /viper/ptmp/arego/LBC/869.h5 is good
# File /viper/ptmp/arego/LBC/2963.h5 is good
# File /viper/ptmp/arego/LBC/3646.h5 is good
# File /viper/ptmp/arego/LBC/1530.h5 is good
# File /viper/ptmp/arego/LBC/5338.h5 is good
# File /viper/ptmp/arego/LBC/3278.h5 is good
# File /viper/ptmp/arego/LBC/370.h5 is good
# File /viper/ptmp/arego/LBC/1954.h5 is good
# File /viper/ptmp/arego/LBC/3935.h5 is good
# File /viper/ptmp/arego/LBC/1162.h5 is good
# File /viper/ptmp/arego/LBC/2502.h5 is good
# File /viper/ptmp/arego/LBC/1297.h5 is good
# File /viper/ptmp/arego/LBC/2213.h5 is good
# File /viper/ptmp/arego/LBC/4560.h5 is good
# File /viper/ptmp/arego/LBC/369.h5 is good
# File /viper/ptmp/arego/LBC/312.h5 is good
# File /viper/ptmp/arego/LBC/180.h5 is good
# File /viper/ptmp/arego/LBC/4192.h5 is good
# File /viper/ptmp/arego/LBC/2637.h5 is good
# File /viper/ptmp/arego/LBC/1586.h5 is good
# File /viper/ptmp/arego/LBC/4984.h5 is good
# File /viper/ptmp/arego/LBC/4329.h5 is good
# File /viper/ptmp/arego/LBC/1204.h5 is good
# File /viper/ptmp/arego/LBC/679.h5 is good
# File /viper/ptmp/arego/LBC/2269.h5 is good
# File /viper/ptmp/arego/LBC/5243.h5 is good
# File /viper/ptmp/arego/LBC/3551.h5 is good
# File /viper/ptmp/arego/LBC/1628.h5 is good
# File /viper/ptmp/arego/LBC/179.h5 is good
# File /viper/ptmp/arego/LBC/844.h5 is good
# File /viper/ptmp/arego/LBC/1339.h5 is good
# File /viper/ptmp/arego/LBC/5299.h5 is good
# File /viper/ptmp/arego/LBC/122.h5 is good
# File /viper/ptmp/arego/LBC/3183.h5 is good
# File /viper/ptmp/arego/LBC/3686.h5 is good
# File /viper/ptmp/arego/LBC/4234.h5 is good
# File /viper/ptmp/arego/LBC/489.h5 is good
# File /viper/ptmp/arego/LBC/1491.h5 is good
# File /viper/ptmp/arego/LBC/3975.h5 is good
# File /viper/ptmp/arego/LBC/1994.h5 is good
# File /viper/ptmp/arego/LBC/4602.h5 is good
# File /viper/ptmp/arego/LBC/2910.h5 is good
# File /viper/ptmp/arego/LBC/2542.h5 is good
# File /viper/ptmp/arego/LBC/4658.h5 is good
# File /viper/ptmp/arego/LBC/2253.h5 is good
# File /viper/ptmp/arego/LBC/4369.h5 is good
# File /viper/ptmp/arego/LBC/1612.h5 is good
# File /viper/ptmp/arego/LBC/81.h5 is good
# File /viper/ptmp/arego/LBC/654.h5 is good
# File /viper/ptmp/arego/LBC/2677.h5 is good
# File /viper/ptmp/arego/LBC/3225.h5 is good
# File /viper/ptmp/arego/LBC/1901.h5 is good
# File /viper/ptmp/arego/LBC/5283.h5 is good
# File /viper/ptmp/arego/LBC/1244.h5 is good
# File /viper/ptmp/arego/LBC/3728.h5 is good
# File /viper/ptmp/arego/LBC/3880.h5 is good
# File /viper/ptmp/arego/LBC/1668.h5 is good
# File /viper/ptmp/arego/LBC/464.h5 is good
# File /viper/ptmp/arego/LBC/1379.h5 is good
# File /viper/ptmp/arego/LBC/299.h5 is good
# File /viper/ptmp/arego/LBC/3591.h5 is good
# File /viper/ptmp/arego/LBC/4931.h5 is good
# File /viper/ptmp/arego/LBC/964.h5 is good
# File /viper/ptmp/arego/LBC/906.h5 is good
# File /viper/ptmp/arego/LBC/4642.h5 is good
# File /viper/ptmp/arego/LBC/4274.h5 is good
# File /viper/ptmp/arego/LBC/2293.h5 is good
# File /viper/ptmp/arego/LBC/2582.h5 is good
# File /viper/ptmp/arego/LBC/406.h5 is good
# File /viper/ptmp/arego/LBC/2719.h5 is good
# File /viper/ptmp/arego/LBC/2950.h5 is good
# File /viper/ptmp/arego/LBC/75.h5 is good
# File /viper/ptmp/arego/LBC/774.h5 is good
# File /viper/ptmp/arego/LBC/5325.h5 is good
# File /viper/ptmp/arego/LBC/3265.h5 is good
# File /viper/ptmp/arego/LBC/1941.h5 is good
# File /viper/ptmp/arego/LBC/4698.h5 is good
# File /viper/ptmp/arego/LBC/3768.h5 is good
# File /viper/ptmp/arego/LBC/3633.h5 is good
# File /viper/ptmp/arego/LBC/4027.h5 is good
# File /viper/ptmp/arego/LBC/1284.h5 is good
# File /viper/ptmp/arego/LBC/1652.h5 is good
# File /viper/ptmp/arego/LBC/274.h5 is good
# File /viper/ptmp/arego/LBC/2200.h5 is good
# File /viper/ptmp/arego/LBC/2335.h5 is good
# File /viper/ptmp/arego/LBC/2759.h5 is good
# File /viper/ptmp/arego/LBC/4971.h5 is good
# File /viper/ptmp/arego/LBC/4316.h5 is good
# File /viper/ptmp/arego/LBC/5230.h5 is good
# File /viper/ptmp/arego/LBC/216.h5 is good
# File /viper/ptmp/arego/LBC/2624.h5 is good
# File /viper/ptmp/arego/LBC/5365.h5 is good
# File /viper/ptmp/arego/LBC/3673.h5 is good
# File /viper/ptmp/arego/LBC/3170.h5 is good
# File /viper/ptmp/arego/LBC/3962.h5 is good
# File /viper/ptmp/arego/LBC/69.h5 is good
# File /viper/ptmp/arego/LBC/3018.h5 is good
# File /viper/ptmp/arego/LBC/2990.h5 is good
# File /viper/ptmp/arego/LBC/1981.h5 is good
# File /viper/ptmp/arego/LBC/4724.h5 is good
# File /viper/ptmp/arego/LBC/1326.h5 is good
# File /viper/ptmp/arego/LBC/32.h5 is good
# File /viper/ptmp/arego/LBC/4221.h5 is good
# File /viper/ptmp/arego/LBC/5039.h5 is good
# File /viper/ptmp/arego/LBC/2009.h5 is good
# File /viper/ptmp/arego/LBC/5270.h5 is good
# File /viper/ptmp/arego/LBC/4356.h5 is good
# File /viper/ptmp/arego/LBC/2240.h5 is good
# File /viper/ptmp/arego/LBC/2375.h5 is good
# File /viper/ptmp/arego/LBC/2664.h5 is good
# File /viper/ptmp/arego/LBC/3058.h5 is good
# File /viper/ptmp/arego/LBC/3347.h5 is good
# File /viper/ptmp/arego/LBC/501.h5 is good
# File /viper/ptmp/arego/LBC/3715.h5 is good
# File /viper/ptmp/arego/LBC/1366.h5 is good
# File /viper/ptmp/arego/LBC/1231.h5 is good
# File /viper/ptmp/arego/LBC/2799.h5 is good
# File /viper/ptmp/arego/LBC/4109.h5 is good
# File /viper/ptmp/arego/LBC/1734.h5 is good
# File /viper/ptmp/arego/LBC/2049.h5 is good
# File /viper/ptmp/arego/LBC/868.h5 is good
# File /viper/ptmp/arego/LBC/4261.h5 is good
# File /viper/ptmp/arego/LBC/2706.h5 is good
# File /viper/ptmp/arego/LBC/2280.h5 is good
# File /viper/ptmp/arego/LBC/2417.h5 is good
# File /viper/ptmp/arego/LBC/5312.h5 is good
# File /viper/ptmp/arego/LBC/311.h5 is good
# File /viper/ptmp/arego/LBC/3331.h5 is good
# File /viper/ptmp/arego/LBC/4685.h5 is good
# File /viper/ptmp/arego/LBC/4396.h5 is good
# File /viper/ptmp/arego/LBC/3620.h5 is good
# File /viper/ptmp/arego/LBC/1408.h5 is good
# File /viper/ptmp/arego/LBC/3755.h5 is good
# File /viper/ptmp/arego/LBC/1271.h5 is good
# File /viper/ptmp/arego/LBC/5079.h5 is good
# File /viper/ptmp/arego/LBC/1119.h5 is good
# File /viper/ptmp/arego/LBC/678.h5 is good
# File /viper/ptmp/arego/LBC/4014.h5 is good
# File /viper/ptmp/arego/LBC/843.h5 is good
# File /viper/ptmp/arego/LBC/4806.h5 is good
# File /viper/ptmp/arego/LBC/4303.h5 is good
# File /viper/ptmp/arego/LBC/3387.h5 is good
# File /viper/ptmp/arego/LBC/3098.h5 is good
# File /viper/ptmp/arego/LBC/4438.h5 is good
# File /viper/ptmp/arego/LBC/2457.h5 is good
# File /viper/ptmp/arego/LBC/1695.h5 is good
# File /viper/ptmp/arego/LBC/2746.h5 is good
# File /viper/ptmp/arego/LBC/121.h5 is good
# File /viper/ptmp/arego/LBC/2322.h5 is good
# File /viper/ptmp/arego/LBC/3005.h5 is good
# File /viper/ptmp/arego/LBC/3429.h5 is good
# File /viper/ptmp/arego/LBC/2089.h5 is good
# File /viper/ptmp/arego/LBC/1024.h5 is good
# File /viper/ptmp/arego/LBC/653.h5 is good
# File /viper/ptmp/arego/LBC/1313.h5 is good
# File /viper/ptmp/arego/LBC/5352.h5 is good
# File /viper/ptmp/arego/LBC/1816.h5 is good
# File /viper/ptmp/arego/LBC/488.h5 is good
# File /viper/ptmp/arego/LBC/1448.h5 is good
# File /viper/ptmp/arego/LBC/3795.h5 is good
# File /viper/ptmp/arego/LBC/3292.h5 is good
# File /viper/ptmp/arego/LBC/3660.h5 is good
# File /viper/ptmp/arego/LBC/4343.h5 is good
# File /viper/ptmp/arego/LBC/4711.h5 is good
# File /viper/ptmp/arego/LBC/4054.h5 is good
# File /viper/ptmp/arego/LBC/298.h5 is good
# File /viper/ptmp/arego/LBC/4846.h5 is good
# File /viper/ptmp/arego/LBC/2362.h5 is good
# File /viper/ptmp/arego/LBC/2651.h5 is good
# File /viper/ptmp/arego/LBC/963.h5 is good
# File /viper/ptmp/arego/LBC/463.h5 is good
# File /viper/ptmp/arego/LBC/1721.h5 is good
# File /viper/ptmp/arego/LBC/2786.h5 is good
# File /viper/ptmp/arego/LBC/4478.h5 is good
# File /viper/ptmp/arego/LBC/905.h5 is good
# File /viper/ptmp/arego/LBC/3045.h5 is good
# File /viper/ptmp/arego/LBC/3702.h5 is good
# File /viper/ptmp/arego/LBC/3413.h5 is good
# File /viper/ptmp/arego/LBC/5026.h5 is good
# File /viper/ptmp/arego/LBC/1064.h5 is good
# File /viper/ptmp/arego/LBC/2404.h5 is good
# File /viper/ptmp/arego/LBC/3837.h5 is good
# File /viper/ptmp/arego/LBC/1488.h5 is good
# File /viper/ptmp/arego/LBC/3469.h5 is good
# File /viper/ptmp/arego/LBC/405.h5 is good
# File /viper/ptmp/arego/LBC/273.h5 is good
# File /viper/ptmp/arego/LBC/773.h5 is good
# File /viper/ptmp/arego/LBC/1777.h5 is good
# File /viper/ptmp/arego/LBC/5010.h5 is good
# File /viper/ptmp/arego/LBC/4751.h5 is good
# File /viper/ptmp/arego/LBC/1353.h5 is good
# File /viper/ptmp/arego/LBC/215.h5 is good
# File /viper/ptmp/arego/LBC/2828.h5 is good
# File /viper/ptmp/arego/LBC/2036.h5 is good
# File /viper/ptmp/arego/LBC/4383.h5 is good
# File /viper/ptmp/arego/LBC/2691.h5 is good
# File /viper/ptmp/arego/LBC/2539.h5 is good
# File /viper/ptmp/arego/LBC/1106.h5 is good
# File /viper/ptmp/arego/LBC/3742.h5 is good
# File /viper/ptmp/arego/LBC/715.h5 is good
# File /viper/ptmp/arego/LBC/4001.h5 is good
# File /viper/ptmp/arego/LBC/5066.h5 is good
# File /viper/ptmp/arego/LBC/1761.h5 is good
# File /viper/ptmp/arego/LBC/583.h5 is good
# File /viper/ptmp/arego/LBC/3877.h5 is good
# File /viper/ptmp/arego/LBC/3374.h5 is good
# File /viper/ptmp/arego/LBC/3085.h5 is good
# File /viper/ptmp/arego/LBC/4425.h5 is good
# File /viper/ptmp/arego/LBC/2020.h5 is good
# File /viper/ptmp/arego/LBC/4136.h5 is good
# File /viper/ptmp/arego/LBC/4928.h5 is good
# File /viper/ptmp/arego/LBC/1393.h5 is good
# File /viper/ptmp/arego/LBC/2076.h5 is good
# File /viper/ptmp/arego/LBC/393.h5 is good
# File /viper/ptmp/arego/LBC/525.h5 is good
# File /viper/ptmp/arego/LBC/2444.h5 is good
# File /viper/ptmp/arego/LBC/2733.h5 is good
# File /viper/ptmp/arego/LBC/5108.h5 is good
# File /viper/ptmp/arego/LBC/4791.h5 is good
# File /viper/ptmp/arego/LBC/2579.h5 is good
# File /viper/ptmp/arego/LBC/3919.h5 is good
# File /viper/ptmp/arego/LBC/1011.h5 is good
# File /viper/ptmp/arego/LBC/2868.h5 is good
# File /viper/ptmp/arego/LBC/1146.h5 is good
# File /viper/ptmp/arego/LBC/3127.h5 is good
# File /viper/ptmp/arego/LBC/74.h5 is good
# File /viper/ptmp/arego/LBC/1803.h5 is good
# File /viper/ptmp/arego/LBC/4330.h5 is good
# File /viper/ptmp/arego/LBC/335.h5 is good
# File /viper/ptmp/arego/LBC/4833.h5 is good
# File /viper/ptmp/arego/LBC/4041.h5 is good
# File /viper/ptmp/arego/LBC/1435.h5 is good
# File /viper/ptmp/arego/LBC/500.h5 is good
# File /viper/ptmp/arego/LBC/2118.h5 is good
# File /viper/ptmp/arego/LBC/1938.h5 is good
# File /viper/ptmp/arego/LBC/3782.h5 is good
# File /viper/ptmp/arego/LBC/4889.h5 is good
# File /viper/ptmp/arego/LBC/3400.h5 is good
# File /viper/ptmp/arego/LBC/4176.h5 is good
# File /viper/ptmp/arego/LBC/2773.h5 is good
# File /viper/ptmp/arego/LBC/867.h5 is good
# File /viper/ptmp/arego/LBC/4465.h5 is good
# File /viper/ptmp/arego/LBC/2484.h5 is good
# File /viper/ptmp/arego/LBC/5148.h5 is good
# File /viper/ptmp/arego/LBC/3032.h5 is good
# File /viper/ptmp/arego/LBC/145.h5 is good
# File /viper/ptmp/arego/LBC/1843.h5 is good
# File /viper/ptmp/arego/LBC/310.h5 is good
# File /viper/ptmp/arego/LBC/1051.h5 is good
# File /viper/ptmp/arego/LBC/3535.h5 is good
# File /viper/ptmp/arego/LBC/3824.h5 is good
# File /viper/ptmp/arego/LBC/3167.h5 is good
# File /viper/ptmp/arego/LBC/2102.h5 is good
# File /viper/ptmp/arego/LBC/1340.h5 is good
# File /viper/ptmp/arego/LBC/809.h5 is good
# File /viper/ptmp/arego/LBC/3959.h5 is good
# File /viper/ptmp/arego/LBC/4507.h5 is good
# File /viper/ptmp/arego/LBC/4370.h5 is good
# File /viper/ptmp/arego/LBC/4218.h5 is good
# File /viper/ptmp/arego/LBC/677.h5 is good
# File /viper/ptmp/arego/LBC/1899.h5 is good
# File /viper/ptmp/arego/LBC/1475.h5 is good
# File /viper/ptmp/arego/LBC/68.h5 is good
# File /viper/ptmp/arego/LBC/2526.h5 is good
# File /viper/ptmp/arego/LBC/4081.h5 is good
# File /viper/ptmp/arego/LBC/2158.h5 is good
# File /viper/ptmp/arego/LBC/842.h5 is good
# File /viper/ptmp/arego/LBC/4873.h5 is good
# File /viper/ptmp/arego/LBC/31.h5 is good
# File /viper/ptmp/arego/LBC/3440.h5 is good
# File /viper/ptmp/arego/LBC/120.h5 is good
# File /viper/ptmp/arego/LBC/1517.h5 is good
# File /viper/ptmp/arego/LBC/3072.h5 is good
# File /viper/ptmp/arego/LBC/5132.h5 is good
# File /viper/ptmp/arego/LBC/1228.h5 is good
# File /viper/ptmp/arego/LBC/619.h5 is good
# File /viper/ptmp/arego/LBC/3864.h5 is good
# File /viper/ptmp/arego/LBC/3209.h5 is good
# File /viper/ptmp/arego/LBC/1380.h5 is good
# File /viper/ptmp/arego/LBC/4123.h5 is good
# File /viper/ptmp/arego/LBC/5188.h5 is good
# File /viper/ptmp/arego/LBC/3496.h5 is good
# File /viper/ptmp/arego/LBC/1091.h5 is good
# File /viper/ptmp/arego/LBC/487.h5 is good
# File /viper/ptmp/arego/LBC/1883.h5 is good
# File /viper/ptmp/arego/LBC/4547.h5 is good
# File /viper/ptmp/arego/LBC/4915.h5 is good
# File /viper/ptmp/arego/LBC/652.h5 is good
# File /viper/ptmp/arego/LBC/2063.h5 is good
# File /viper/ptmp/arego/LBC/3999.h5 is good
# File /viper/ptmp/arego/LBC/2431.h5 is good
# File /viper/ptmp/arego/LBC/429.h5 is good
# File /viper/ptmp/arego/LBC/2566.h5 is good
# File /viper/ptmp/arego/LBC/2198.h5 is good
# File /viper/ptmp/arego/LBC/4258.h5 is good
# File /viper/ptmp/arego/LBC/297.h5 is good
# File /viper/ptmp/arego/LBC/2855.h5 is good
# File /viper/ptmp/arego/LBC/3617.h5 is good
# File /viper/ptmp/arego/LBC/1133.h5 is good
# File /viper/ptmp/arego/LBC/3114.h5 is good
# File /viper/ptmp/arego/LBC/462.h5 is good
# File /viper/ptmp/arego/LBC/3906.h5 is good
# File /viper/ptmp/arego/LBC/5093.h5 is good
# File /viper/ptmp/arego/LBC/3249.h5 is good
# File /viper/ptmp/arego/LBC/1925.h5 is good
# File /viper/ptmp/arego/LBC/1422.h5 is good
# File /viper/ptmp/arego/LBC/962.h5 is good
# File /viper/ptmp/arego/LBC/3480.h5 is good
# File /viper/ptmp/arego/LBC/4163.h5 is good
# File /viper/ptmp/arego/LBC/239.h5 is good
# File /viper/ptmp/arego/LBC/904.h5 is good
# File /viper/ptmp/arego/LBC/4452.h5 is good
# File /viper/ptmp/arego/LBC/1268.h5 is good
# File /viper/ptmp/arego/LBC/1557.h5 is good
# File /viper/ptmp/arego/LBC/2608.h5 is good
# File /viper/ptmp/arego/LBC/4820.h5 is good
# File /viper/ptmp/arego/LBC/404.h5 is good
# File /viper/ptmp/arego/LBC/4955.h5 is good
# File /viper/ptmp/arego/LBC/272.h5 is good
# File /viper/ptmp/arego/LBC/2471.h5 is good
# File /viper/ptmp/arego/LBC/5214.h5 is good
# File /viper/ptmp/arego/LBC/772.h5 is good
# File /viper/ptmp/arego/LBC/4587.h5 is good
# File /viper/ptmp/arego/LBC/2895.h5 is good
# File /viper/ptmp/arego/LBC/714.h5 is good
# File /viper/ptmp/arego/LBC/3522.h5 is good
# File /viper/ptmp/arego/LBC/214.h5 is good
# File /viper/ptmp/arego/LBC/3154.h5 is good
# File /viper/ptmp/arego/LBC/3811.h5 is good
# File /viper/ptmp/arego/LBC/1830.h5 is good
# File /viper/ptmp/arego/LBC/4205.h5 is good
# File /viper/ptmp/arego/LBC/3946.h5 is good
# File /viper/ptmp/arego/LBC/1173.h5 is good
# File /viper/ptmp/arego/LBC/2513.h5 is good
# File /viper/ptmp/arego/LBC/1965.h5 is good
# File /viper/ptmp/arego/LBC/1462.h5 is good
# File /viper/ptmp/arego/LBC/1597.h5 is good
# File /viper/ptmp/arego/LBC/2224.h5 is good
# File /viper/ptmp/arego/LBC/3289.h5 is good
# File /viper/ptmp/arego/LBC/4629.h5 is good
# File /viper/ptmp/arego/LBC/2648.h5 is good
# File /viper/ptmp/arego/LBC/582.h5 is good
# File /viper/ptmp/arego/LBC/3578.h5 is good
# File /viper/ptmp/arego/LBC/2937.h5 is good
# File /viper/ptmp/arego/LBC/4492.h5 is good
# File /viper/ptmp/arego/LBC/1215.h5 is good
# File /viper/ptmp/arego/LBC/4995.h5 is good
# File /viper/ptmp/arego/LBC/4860.h5 is good
# File /viper/ptmp/arego/LBC/4110.h5 is good
# File /viper/ptmp/arego/LBC/3562.h5 is good
# File /viper/ptmp/arego/LBC/3194.h5 is good
# File /viper/ptmp/arego/LBC/524.h5 is good
# File /viper/ptmp/arego/LBC/5175.h5 is good
# File /viper/ptmp/arego/LBC/3851.h5 is good
# File /viper/ptmp/arego/LBC/4902.h5 is good
# File /viper/ptmp/arego/LBC/4245.h5 is good
# File /viper/ptmp/arego/LBC/4534.h5 is good
# File /viper/ptmp/arego/LBC/392.h5 is good
# File /viper/ptmp/arego/LBC/2553.h5 is good
# File /viper/ptmp/arego/LBC/2921.h5 is good
# File /viper/ptmp/arego/LBC/1639.h5 is good
# File /viper/ptmp/arego/LBC/1870.h5 is good
# File /viper/ptmp/arego/LBC/3986.h5 is good
# File /viper/ptmp/arego/LBC/334.h5 is good
# File /viper/ptmp/arego/LBC/4669.h5 is good
# File /viper/ptmp/arego/LBC/2185.h5 is good
# File /viper/ptmp/arego/LBC/1120.h5 is good
# File /viper/ptmp/arego/LBC/3101.h5 is good
# File /viper/ptmp/arego/LBC/3236.h5 is good
# File /viper/ptmp/arego/LBC/2688.h5 is good
# File /viper/ptmp/arego/LBC/2977.h5 is good
# File /viper/ptmp/arego/LBC/3604.h5 is good
# File /viper/ptmp/arego/LBC/1255.h5 is good
# File /viper/ptmp/arego/LBC/1912.h5 is good
# File /viper/ptmp/arego/LBC/3739.h5 is good
# File /viper/ptmp/arego/LBC/1544.h5 is good
# File /viper/ptmp/arego/LBC/866.h5 is good
# File /viper/ptmp/arego/LBC/3891.h5 is good
# File /viper/ptmp/arego/LBC/5201.h5 is good
# File /viper/ptmp/arego/LBC/4150.h5 is good
# File /viper/ptmp/arego/LBC/1679.h5 is good
# File /viper/ptmp/arego/LBC/144.h5 is good
# File /viper/ptmp/arego/LBC/2306.h5 is good
# File /viper/ptmp/arego/LBC/4285.h5 is good
# File /viper/ptmp/arego/LBC/808.h5 is good
# File /viper/ptmp/arego/LBC/4942.h5 is good
# File /viper/ptmp/arego/LBC/2593.h5 is good
# File /viper/ptmp/arego/LBC/4574.h5 is good
# File /viper/ptmp/arego/LBC/2882.h5 is good
# File /viper/ptmp/arego/LBC/3644.h5 is good
# File /viper/ptmp/arego/LBC/3141.h5 is good
# File /viper/ptmp/arego/LBC/676.h5 is good
# File /viper/ptmp/arego/LBC/1160.h5 is good
# File /viper/ptmp/arego/LBC/5257.h5 is good
# File /viper/ptmp/arego/LBC/618.h5 is good
# File /viper/ptmp/arego/LBC/3276.h5 is good
# File /viper/ptmp/arego/LBC/3933.h5 is good
# File /viper/ptmp/arego/LBC/1295.h5 is good
# File /viper/ptmp/arego/LBC/2500.h5 is good
# File /viper/ptmp/arego/LBC/4616.h5 is good
# File /viper/ptmp/arego/LBC/2635.h5 is good
# File /viper/ptmp/arego/LBC/1584.h5 is good
# File /viper/ptmp/arego/LBC/2211.h5 is good
# File /viper/ptmp/arego/LBC/1952.h5 is good
# File /viper/ptmp/arego/LBC/486.h5 is good
# File /viper/ptmp/arego/LBC/4327.h5 is good
# File /viper/ptmp/arego/LBC/4190.h5 is good
# File /viper/ptmp/arego/LBC/986.h5 is good
# File /viper/ptmp/arego/LBC/73.h5 is good
# File /viper/ptmp/arego/LBC/2267.h5 is good
# File /viper/ptmp/arego/LBC/3029.h5 is good
# File /viper/ptmp/arego/LBC/4982.h5 is good
# File /viper/ptmp/arego/LBC/3318.h5 is good
# File /viper/ptmp/arego/LBC/5241.h5 is good
# File /viper/ptmp/arego/LBC/928.h5 is good
# File /viper/ptmp/arego/LBC/1202.h5 is good
# File /viper/ptmp/arego/LBC/3181.h5 is good
# File /viper/ptmp/arego/LBC/1337.h5 is good
# File /viper/ptmp/arego/LBC/4600.h5 is good
# File /viper/ptmp/arego/LBC/5297.h5 is good
# File /viper/ptmp/arego/LBC/3684.h5 is good
# File /viper/ptmp/arego/LBC/428.h5 is good
# File /viper/ptmp/arego/LBC/1626.h5 is good
# File /viper/ptmp/arego/LBC/4232.h5 is good
# File /viper/ptmp/arego/LBC/1992.h5 is good
# File /viper/ptmp/arego/LBC/3973.h5 is good
# File /viper/ptmp/arego/LBC/2251.h5 is good
# File /viper/ptmp/arego/LBC/796.h5 is good
# File /viper/ptmp/arego/LBC/4367.h5 is good
# File /viper/ptmp/arego/LBC/4656.h5 is good
# File /viper/ptmp/arego/LBC/296.h5 is good
# File /viper/ptmp/arego/LBC/961.h5 is good
# File /viper/ptmp/arego/LBC/2540.h5 is good
# File /viper/ptmp/arego/LBC/2675.h5 is good
# File /viper/ptmp/arego/LBC/461.h5 is good
# File /viper/ptmp/arego/LBC/738.h5 is good
# File /viper/ptmp/arego/LBC/3223.h5 is good
# File /viper/ptmp/arego/LBC/67.h5 is good
# File /viper/ptmp/arego/LBC/403.h5 is good
# File /viper/ptmp/arego/LBC/238.h5 is good
# File /viper/ptmp/arego/LBC/903.h5 is good
# File /viper/ptmp/arego/LBC/3726.h5 is good
# File /viper/ptmp/arego/LBC/271.h5 is good
# File /viper/ptmp/arego/LBC/1610.h5 is good
# File /viper/ptmp/arego/LBC/771.h5 is good
# File /viper/ptmp/arego/LBC/5281.h5 is good
# File /viper/ptmp/arego/LBC/1242.h5 is good
# File /viper/ptmp/arego/LBC/30.h5 is good
# File /viper/ptmp/arego/LBC/3358.h5 is good
# File /viper/ptmp/arego/LBC/1377.h5 is good
# File /viper/ptmp/arego/LBC/4272.h5 is good
# File /viper/ptmp/arego/LBC/713.h5 is good
# File /viper/ptmp/arego/LBC/213.h5 is good
# File /viper/ptmp/arego/LBC/4640.h5 is good
# File /viper/ptmp/arego/LBC/2580.h5 is good
# File /viper/ptmp/arego/LBC/4409.h5 is good
# File /viper/ptmp/arego/LBC/1666.h5 is good
# File /viper/ptmp/arego/LBC/581.h5 is good
# File /viper/ptmp/arego/LBC/2717.h5 is good
# File /viper/ptmp/arego/LBC/3631.h5 is good
# File /viper/ptmp/arego/LBC/4696.h5 is good
# File /viper/ptmp/arego/LBC/1419.h5 is good
# File /viper/ptmp/arego/LBC/2349.h5 is good
# File /viper/ptmp/arego/LBC/5323.h5 is good
# File /viper/ptmp/arego/LBC/3766.h5 is good
# File /viper/ptmp/arego/LBC/1282.h5 is good
# File /viper/ptmp/arego/LBC/5379.h5 is good
# File /viper/ptmp/arego/LBC/1708.h5 is good
# File /viper/ptmp/arego/LBC/3263.h5 is good
# File /viper/ptmp/arego/LBC/1571.h5 is good
# File /viper/ptmp/arego/LBC/523.h5 is good
# File /viper/ptmp/arego/LBC/2622.h5 is good
# File /viper/ptmp/arego/LBC/4449.h5 is good
# File /viper/ptmp/arego/LBC/4738.h5 is good
# File /viper/ptmp/arego/LBC/2333.h5 is good
# File /viper/ptmp/arego/LBC/4314.h5 is good
# File /viper/ptmp/arego/LBC/3398.h5 is good
# File /viper/ptmp/arego/LBC/333.h5 is good
# File /viper/ptmp/arego/LBC/391.h5 is good
# File /viper/ptmp/arego/LBC/2389.h5 is good
# File /viper/ptmp/arego/LBC/5363.h5 is good
# File /viper/ptmp/arego/LBC/3016.h5 is good
# File /viper/ptmp/arego/LBC/3305.h5 is good
# File /viper/ptmp/arego/LBC/2757.h5 is good
# File /viper/ptmp/arego/LBC/1748.h5 is good
# File /viper/ptmp/arego/LBC/3808.h5 is good
# File /viper/ptmp/arego/LBC/1324.h5 is good
# File /viper/ptmp/arego/LBC/3671.h5 is good
# File /viper/ptmp/arego/LBC/1459.h5 is good
# File /viper/ptmp/arego/LBC/3960.h5 is good
# File /viper/ptmp/arego/LBC/2373.h5 is good
# File /viper/ptmp/arego/LBC/4722.h5 is good
# File /viper/ptmp/arego/LBC/2662.h5 is good
# File /viper/ptmp/arego/LBC/4354.h5 is good
# File /viper/ptmp/arego/LBC/865.h5 is good
# File /viper/ptmp/arego/LBC/2007.h5 is good
# File /viper/ptmp/arego/LBC/5037.h5 is good
# File /viper/ptmp/arego/LBC/807.h5 is good
# File /viper/ptmp/arego/LBC/4489.h5 is good
# File /viper/ptmp/arego/LBC/4778.h5 is good
# File /viper/ptmp/arego/LBC/3713.h5 is good
# File /viper/ptmp/arego/LBC/143.h5 is good
# File /viper/ptmp/arego/LBC/3056.h5 is good
# File /viper/ptmp/arego/LBC/1732.h5 is good
# File /viper/ptmp/arego/LBC/1364.h5 is good
# File /viper/ptmp/arego/LBC/2797.h5 is good
# File /viper/ptmp/arego/LBC/3345.h5 is good
# File /viper/ptmp/arego/LBC/1499.h5 is good
# File /viper/ptmp/arego/LBC/2047.h5 is good
# File /viper/ptmp/arego/LBC/3848.h5 is good
# File /viper/ptmp/arego/LBC/4107.h5 is good
# File /viper/ptmp/arego/LBC/2704.h5 is good
# File /viper/ptmp/arego/LBC/675.h5 is good
# File /viper/ptmp/arego/LBC/2415.h5 is good
# File /viper/ptmp/arego/LBC/4683.h5 is good
# File /viper/ptmp/arego/LBC/1788.h5 is good
# File /viper/ptmp/arego/LBC/5310.h5 is good
# File /viper/ptmp/arego/LBC/617.h5 is good
# File /viper/ptmp/arego/LBC/4394.h5 is good
# File /viper/ptmp/arego/LBC/2839.h5 is good
# File /viper/ptmp/arego/LBC/985.h5 is good
# File /viper/ptmp/arego/LBC/485.h5 is good
# File /viper/ptmp/arego/LBC/1406.h5 is good
# File /viper/ptmp/arego/LBC/1038.h5 is good
# File /viper/ptmp/arego/LBC/5077.h5 is good
# File /viper/ptmp/arego/LBC/4301.h5 is good
# File /viper/ptmp/arego/LBC/927.h5 is good
# File /viper/ptmp/arego/LBC/4012.h5 is good
# File /viper/ptmp/arego/LBC/3753.h5 is good
# File /viper/ptmp/arego/LBC/3385.h5 is good
# File /viper/ptmp/arego/LBC/4804.h5 is good
# File /viper/ptmp/arego/LBC/427.h5 is good
# File /viper/ptmp/arego/LBC/3096.h5 is good
# File /viper/ptmp/arego/LBC/4068.h5 is good
# File /viper/ptmp/arego/LBC/2320.h5 is good
# File /viper/ptmp/arego/LBC/4436.h5 is good
# File /viper/ptmp/arego/LBC/3888.h5 is good
# File /viper/ptmp/arego/LBC/1693.h5 is good
# File /viper/ptmp/arego/LBC/2455.h5 is good
# File /viper/ptmp/arego/LBC/2744.h5 is good
# File /viper/ptmp/arego/LBC/795.h5 is good
# File /viper/ptmp/arego/LBC/2087.h5 is good
# File /viper/ptmp/arego/LBC/1311.h5 is good
# File /viper/ptmp/arego/LBC/5350.h5 is good
# File /viper/ptmp/arego/LBC/295.h5 is good
# File /viper/ptmp/arego/LBC/960.h5 is good
# File /viper/ptmp/arego/LBC/3003.h5 is good
# File /viper/ptmp/arego/LBC/3138.h5 is good
# File /viper/ptmp/arego/LBC/737.h5 is good
# File /viper/ptmp/arego/LBC/5119.h5 is good
# File /viper/ptmp/arego/LBC/1022.h5 is good
# File /viper/ptmp/arego/LBC/1814.h5 is good
# File /viper/ptmp/arego/LBC/902.h5 is good
# File /viper/ptmp/arego/LBC/2879.h5 is good
# File /viper/ptmp/arego/LBC/3427.h5 is good
# File /viper/ptmp/arego/LBC/237.h5 is good
# File /viper/ptmp/arego/LBC/3290.h5 is good
# File /viper/ptmp/arego/LBC/1446.h5 is good
# File /viper/ptmp/arego/LBC/1078.h5 is good
# File /viper/ptmp/arego/LBC/770.h5 is good
# File /viper/ptmp/arego/LBC/3793.h5 is good
# File /viper/ptmp/arego/LBC/4341.h5 is good
# File /viper/ptmp/arego/LBC/4844.h5 is good
# File /viper/ptmp/arego/LBC/4052.h5 is good
# File /viper/ptmp/arego/LBC/547.h5 is good
# File /viper/ptmp/arego/LBC/2360.h5 is good
# File /viper/ptmp/arego/LBC/4476.h5 is good
# File /viper/ptmp/arego/LBC/2129.h5 is good
# File /viper/ptmp/arego/LBC/3043.h5 is good
# File /viper/ptmp/arego/LBC/5159.h5 is good
# File /viper/ptmp/arego/LBC/72.h5 is good
# File /viper/ptmp/arego/LBC/3700.h5 is good
# File /viper/ptmp/arego/LBC/5024.h5 is good
# File /viper/ptmp/arego/LBC/2784.h5 is good
# File /viper/ptmp/arego/LBC/3411.h5 is good
# File /viper/ptmp/arego/LBC/3835.h5 is good
# File /viper/ptmp/arego/LBC/712.h5 is good
# File /viper/ptmp/arego/LBC/3467.h5 is good
# File /viper/ptmp/arego/LBC/3178.h5 is good
# File /viper/ptmp/arego/LBC/2402.h5 is good
# File /viper/ptmp/arego/LBC/1062.h5 is good
# File /viper/ptmp/arego/LBC/580.h5 is good
# File /viper/ptmp/arego/LBC/357.h5 is good
# File /viper/ptmp/arego/LBC/1351.h5 is good
# File /viper/ptmp/arego/LBC/1486.h5 is good
# File /viper/ptmp/arego/LBC/1775.h5 is good
# File /viper/ptmp/arego/LBC/2537.h5 is good
# File /viper/ptmp/arego/LBC/522.h5 is good
# File /viper/ptmp/arego/LBC/4381.h5 is good
# File /viper/ptmp/arego/LBC/4518.h5 is good
# File /viper/ptmp/arego/LBC/2034.h5 is good
# File /viper/ptmp/arego/LBC/1104.h5 is good
# File /viper/ptmp/arego/LBC/2826.h5 is good
# File /viper/ptmp/arego/LBC/3740.h5 is good
# File /viper/ptmp/arego/LBC/3509.h5 is good
# File /viper/ptmp/arego/LBC/390.h5 is good
# File /viper/ptmp/arego/LBC/2169.h5 is good
# File /viper/ptmp/arego/LBC/5064.h5 is good
# File /viper/ptmp/arego/LBC/1528.h5 is good
# File /viper/ptmp/arego/LBC/889.h5 is good
# File /viper/ptmp/arego/LBC/66.h5 is good
# File /viper/ptmp/arego/LBC/3083.h5 is good
# File /viper/ptmp/arego/LBC/1391.h5 is good
# File /viper/ptmp/arego/LBC/5199.h5 is good
# File /viper/ptmp/arego/LBC/167.h5 is good
# File /viper/ptmp/arego/LBC/3372.h5 is good
# File /viper/ptmp/arego/LBC/332.h5 is good
# File /viper/ptmp/arego/LBC/3875.h5 is good
# File /viper/ptmp/arego/LBC/2731.h5 is good
# File /viper/ptmp/arego/LBC/109.h5 is good
# File /viper/ptmp/arego/LBC/4134.h5 is good
# File /viper/ptmp/arego/LBC/4423.h5 is good
# File /viper/ptmp/arego/LBC/2442.h5 is good
# File /viper/ptmp/arego/LBC/4926.h5 is good
# File /viper/ptmp/arego/LBC/2866.h5 is good
# File /viper/ptmp/arego/LBC/2074.h5 is good
# File /viper/ptmp/arego/LBC/864.h5 is good
# File /viper/ptmp/arego/LBC/4558.h5 is good
# File /viper/ptmp/arego/LBC/2577.h5 is good
# File /viper/ptmp/arego/LBC/5106.h5 is good
# File /viper/ptmp/arego/LBC/142.h5 is good
# File /viper/ptmp/arego/LBC/3549.h5 is good
# File /viper/ptmp/arego/LBC/1801.h5 is good
# File /viper/ptmp/arego/LBC/699.h5 is good
# File /viper/ptmp/arego/LBC/3125.h5 is good
# File /viper/ptmp/arego/LBC/1936.h5 is good
# File /viper/ptmp/arego/LBC/3917.h5 is good
# File /viper/ptmp/arego/LBC/1433.h5 is good
# File /viper/ptmp/arego/LBC/806.h5 is good
# File /viper/ptmp/arego/LBC/3780.h5 is good
# File /viper/ptmp/arego/LBC/1144.h5 is good
# File /viper/ptmp/arego/LBC/1568.h5 is good
# File /viper/ptmp/arego/LBC/2908.h5 is good
# File /viper/ptmp/arego/LBC/2619.h5 is good
# File /viper/ptmp/arego/LBC/674.h5 is good
# File /viper/ptmp/arego/LBC/4831.h5 is good
# File /viper/ptmp/arego/LBC/2116.h5 is good
# File /viper/ptmp/arego/LBC/4463.h5 is good
# File /viper/ptmp/arego/LBC/3030.h5 is good
# File /viper/ptmp/arego/LBC/4887.h5 is good
# File /viper/ptmp/arego/LBC/4095.h5 is good
# File /viper/ptmp/arego/LBC/2771.h5 is good
# File /viper/ptmp/arego/LBC/5146.h5 is good
# File /viper/ptmp/arego/LBC/23.h5 is good
# File /viper/ptmp/arego/LBC/3822.h5 is good
# File /viper/ptmp/arego/LBC/4598.h5 is good
# File /viper/ptmp/arego/LBC/2482.h5 is good
# File /viper/ptmp/arego/LBC/3165.h5 is good
# File /viper/ptmp/arego/LBC/616.h5 is good
# File /viper/ptmp/arego/LBC/1841.h5 is good
# File /viper/ptmp/arego/LBC/3454.h5 is good
# File /viper/ptmp/arego/LBC/4216.h5 is good
# File /viper/ptmp/arego/LBC/4505.h5 is good
# File /viper/ptmp/arego/LBC/3957.h5 is good
# File /viper/ptmp/arego/LBC/1473.h5 is good
# File /viper/ptmp/arego/LBC/984.h5 is good
# File /viper/ptmp/arego/LBC/2524.h5 is good
# File /viper/ptmp/arego/LBC/2100.h5 is good
# File /viper/ptmp/arego/LBC/484.h5 is good
# File /viper/ptmp/arego/LBC/3589.h5 is good
# File /viper/ptmp/arego/LBC/926.h5 is good
# File /viper/ptmp/arego/LBC/2948.h5 is good
# File /viper/ptmp/arego/LBC/2156.h5 is good
# File /viper/ptmp/arego/LBC/2813.h5 is good
# File /viper/ptmp/arego/LBC/1897.h5 is good
# File /viper/ptmp/arego/LBC/426.h5 is good
# File /viper/ptmp/arego/LBC/4871.h5 is good
# File /viper/ptmp/arego/LBC/5051.h5 is good
# File /viper/ptmp/arego/LBC/2659.h5 is good
# File /viper/ptmp/arego/LBC/3070.h5 is good
# File /viper/ptmp/arego/LBC/294.h5 is good
# File /viper/ptmp/arego/LBC/4.h5 is good
# File /viper/ptmp/arego/LBC/3207.h5 is good
# File /viper/ptmp/arego/LBC/3862.h5 is good
# File /viper/ptmp/arego/LBC/1515.h5 is good
# File /viper/ptmp/arego/LBC/794.h5 is good
# File /viper/ptmp/arego/LBC/5186.h5 is good
# File /viper/ptmp/arego/LBC/1226.h5 is good
# File /viper/ptmp/arego/LBC/4410.h5 is good
# File /viper/ptmp/arego/LBC/3494.h5 is good
# File /viper/ptmp/arego/LBC/3997.h5 is good
# File /viper/ptmp/arego/LBC/1881.h5 is good
# File /viper/ptmp/arego/LBC/4121.h5 is good
# File /viper/ptmp/arego/LBC/4913.h5 is good
# File /viper/ptmp/arego/LBC/4256.h5 is good
# File /viper/ptmp/arego/LBC/236.h5 is good
# File /viper/ptmp/arego/LBC/736.h5 is good
# File /viper/ptmp/arego/LBC/901.h5 is good
# File /viper/ptmp/arego/LBC/4545.h5 is good
# File /viper/ptmp/arego/LBC/2061.h5 is good
# File /viper/ptmp/arego/LBC/2564.h5 is good
# File /viper/ptmp/arego/LBC/2853.h5 is good
# File /viper/ptmp/arego/LBC/4969.h5 is good
# File /viper/ptmp/arego/LBC/3904.h5 is good
# File /viper/ptmp/arego/LBC/3112.h5 is good
# File /viper/ptmp/arego/LBC/2196.h5 is good
# File /viper/ptmp/arego/LBC/3615.h5 is good
# File /viper/ptmp/arego/LBC/5091.h5 is good
# File /viper/ptmp/arego/LBC/2988.h5 is good
# File /viper/ptmp/arego/LBC/1420.h5 is good
# File /viper/ptmp/arego/LBC/5228.h5 is good
# File /viper/ptmp/arego/LBC/1131.h5 is good
# File /viper/ptmp/arego/LBC/3247.h5 is good
# File /viper/ptmp/arego/LBC/1923.h5 is good
# File /viper/ptmp/arego/LBC/711.h5 is good
# File /viper/ptmp/arego/LBC/1555.h5 is good
# File /viper/ptmp/arego/LBC/1187.h5 is good
# File /viper/ptmp/arego/LBC/4161.h5 is good
# File /viper/ptmp/arego/LBC/2238.h5 is good
# File /viper/ptmp/arego/LBC/546.h5 is good
# File /viper/ptmp/arego/LBC/4450.h5 is good
# File /viper/ptmp/arego/LBC/4585.h5 is good
# File /viper/ptmp/arego/LBC/2606.h5 is good
# File /viper/ptmp/arego/LBC/4953.h5 is good
# File /viper/ptmp/arego/LBC/356.h5 is good
# File /viper/ptmp/arego/LBC/3520.h5 is good
# File /viper/ptmp/arego/LBC/1979.h5 is good
# File /viper/ptmp/arego/LBC/5212.h5 is good
# File /viper/ptmp/arego/LBC/521.h5 is good
# File /viper/ptmp/arego/LBC/2893.h5 is good
# File /viper/ptmp/arego/LBC/1171.h5 is good
# File /viper/ptmp/arego/LBC/3944.h5 is good
# File /viper/ptmp/arego/LBC/1460.h5 is good
# File /viper/ptmp/arego/LBC/3152.h5 is good
# File /viper/ptmp/arego/LBC/1308.h5 is good
# File /viper/ptmp/arego/LBC/3576.h5 is good
# File /viper/ptmp/arego/LBC/5268.h5 is good
# File /viper/ptmp/arego/LBC/4203.h5 is good
# File /viper/ptmp/arego/LBC/3287.h5 is good
# File /viper/ptmp/arego/LBC/4338.h5 is good
# File /viper/ptmp/arego/LBC/2511.h5 is good
# File /viper/ptmp/arego/LBC/1963.h5 is good
# File /viper/ptmp/arego/LBC/1595.h5 is good
# File /viper/ptmp/arego/LBC/166.h5 is good
# File /viper/ptmp/arego/LBC/4627.h5 is good
# File /viper/ptmp/arego/LBC/4490.h5 is good
# File /viper/ptmp/arego/LBC/888.h5 is good
# File /viper/ptmp/arego/LBC/2143.h5 is good
# File /viper/ptmp/arego/LBC/2935.h5 is good
# File /viper/ptmp/arego/LBC/331.h5 is good
# File /viper/ptmp/arego/LBC/2646.h5 is good
# File /viper/ptmp/arego/LBC/2278.h5 is good
# File /viper/ptmp/arego/LBC/3329.h5 is good
# File /viper/ptmp/arego/LBC/5173.h5 is good
# File /viper/ptmp/arego/LBC/4993.h5 is good
# File /viper/ptmp/arego/LBC/108.h5 is good
# File /viper/ptmp/arego/LBC/1213.h5 is good
# File /viper/ptmp/arego/LBC/1502.h5 is good
# File /viper/ptmp/arego/LBC/3984.h5 is good
# File /viper/ptmp/arego/LBC/698.h5 is good
# File /viper/ptmp/arego/LBC/4900.h5 is good
# File /viper/ptmp/arego/LBC/3192.h5 is good
# File /viper/ptmp/arego/LBC/1348.h5 is good
# File /viper/ptmp/arego/LBC/3560.h5 is good
# File /viper/ptmp/arego/LBC/4243.h5 is good
# File /viper/ptmp/arego/LBC/3602.h5 is good
# File /viper/ptmp/arego/LBC/2551.h5 is good
# File /viper/ptmp/arego/LBC/4667.h5 is good
# File /viper/ptmp/arego/LBC/1637.h5 is good
# File /viper/ptmp/arego/LBC/2183.h5 is good
# File /viper/ptmp/arego/LBC/4532.h5 is good
# File /viper/ptmp/arego/LBC/3234.h5 is good
# File /viper/ptmp/arego/LBC/141.h5 is good
# File /viper/ptmp/arego/LBC/2686.h5 is good
# File /viper/ptmp/arego/LBC/3369.h5 is good
# File /viper/ptmp/arego/LBC/1253.h5 is good
# File /viper/ptmp/arego/LBC/2975.h5 is good
# File /viper/ptmp/arego/LBC/4299.h5 is good
# File /viper/ptmp/arego/LBC/1910.h5 is good
# File /viper/ptmp/arego/LBC/1677.h5 is good
# File /viper/ptmp/arego/LBC/4709.h5 is good
# File /viper/ptmp/arego/LBC/2304.h5 is good
# File /viper/ptmp/arego/LBC/4940.h5 is good
# File /viper/ptmp/arego/LBC/1542.h5 is good
# File /viper/ptmp/arego/LBC/3658.h5 is good
# File /viper/ptmp/arego/LBC/2591.h5 is good
# File /viper/ptmp/arego/LBC/4283.h5 is good
# File /viper/ptmp/arego/LBC/65.h5 is good
# File /viper/ptmp/arego/LBC/3642.h5 is good
# File /viper/ptmp/arego/LBC/4572.h5 is good
# File /viper/ptmp/arego/LBC/983.h5 is good
# File /viper/ptmp/arego/LBC/2728.h5 is good
# File /viper/ptmp/arego/LBC/3274.h5 is good
# File /viper/ptmp/arego/LBC/2880.h5 is good
# File /viper/ptmp/arego/LBC/3931.h5 is good
# File /viper/ptmp/arego/LBC/5255.h5 is good
# File /viper/ptmp/arego/LBC/1293.h5 is good
# File /viper/ptmp/arego/LBC/4325.h5 is good
# File /viper/ptmp/arego/LBC/925.h5 is good
# File /viper/ptmp/arego/LBC/1719.h5 is good
# File /viper/ptmp/arego/LBC/425.h5 is good
# File /viper/ptmp/arego/LBC/793.h5 is good
# File /viper/ptmp/arego/LBC/4749.h5 is good
# File /viper/ptmp/arego/LBC/1950.h5 is good
# File /viper/ptmp/arego/LBC/3698.h5 is good
# File /viper/ptmp/arego/LBC/4980.h5 is good
# File /viper/ptmp/arego/LBC/1582.h5 is good
# File /viper/ptmp/arego/LBC/4614.h5 is good
# File /viper/ptmp/arego/LBC/235.h5 is good
# File /viper/ptmp/arego/LBC/2633.h5 is good
# File /viper/ptmp/arego/LBC/59.h5 is good
# File /viper/ptmp/arego/LBC/5008.h5 is good
# File /viper/ptmp/arego/LBC/3027.h5 is good
# File /viper/ptmp/arego/LBC/735.h5 is good
# File /viper/ptmp/arego/LBC/2265.h5 is good
# File /viper/ptmp/arego/LBC/1200.h5 is good
# File /viper/ptmp/arego/LBC/2768.h5 is good
# ...
# 🗑️ Deleted: /viper/ptmp/arego/LBC/1929.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/1137.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/3773.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/1792.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/84.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/2051.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/4032.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/4824.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/5097.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/2340.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/848.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/348.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/4167.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/5218.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/1410.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/4456.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/2843.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/5081.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/4959.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/3102.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/2475.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/3815.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/1042.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/3158.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/2899.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/881.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/3526.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/5370.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/1834.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/158.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/1177.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/1466.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/658.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/823.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/4209.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/2228.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/4440.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/2517.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/78.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/5123.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/2091.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/1969.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/4864.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/4072.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/2380.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/2883.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/4496.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/5258.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/691.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/3431.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/468.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/4999.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/3063.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/3855.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/1450.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/633.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/3566.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/4114.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/1219.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/41.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/3198.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/1082.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/1874.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/4617.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/278.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/2422.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/2925.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/4249.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/4906.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/443.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/2133.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/1124.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/3471.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/5163.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/2557.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/2189.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/3608.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/3760.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/1916.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/1259.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/4522.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/1548.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/2830.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/4811.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/3895.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/4154.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/4946.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/253.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/2173.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/4289.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/4578.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/2462.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/5205.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/2965.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/3513.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/1821.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/3937.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/3648.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/3145.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/2597.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/1164.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/1532.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/1956.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/2215.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/2504.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/1588.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/4562.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/4851.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/1299.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/4194.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/5110.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/2639.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/3921.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/4986.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/2870.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/5245.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/4101.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/3553.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/1709.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/1206.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/537.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/4604.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/3185.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/1861.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/2120.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/2255.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/3688.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/3977.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/1493.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/4236.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/2912.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/1996.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/5150.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/2679.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/2544.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/847.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/1614.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/4891.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/1111.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/347.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/1903.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/3227.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/3090.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/1246.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/3882.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/880.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/5285.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/3593.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/4141.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/157.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/4644.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/2952.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/2160.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/4933.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/657.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/3211.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/4276.h5
# Column 'event_no' not found in /hits/table, deleting file.
# 🗑️ Deleted: /viper/ptmp/arego/LBC/3500.h5
#
# ✅ Summary: 1381 files deleted, 4000 files kept.
# ✅ Processing complete!
