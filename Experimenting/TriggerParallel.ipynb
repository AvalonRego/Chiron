# %%
import sys
sys.path.append('../../olympus/lib/python3.10/site-packages/')
import logging
from ananke.models.collection import Collection
from ananke.configurations.collection import HDF5StorageConfiguration
logging.getLogger().setLevel(logging.INFO)
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)
import time
from joblib import Parallel, delayed

# %%
path="data/test/Cascade100(copy).h5"

# %%
from importlib import reload
import trigger_copy_1
import trigger_copy
reload(trigger_copy_1)
reload(trigger_copy)
import trigger_copy_1 as tc1
from trigger_copy  import TriggerDatasetProcessor as TDP2

# %%
process=TDP2(path)

# %%
start=time.time()
a=process.run()
print(time.time()-start)
# Out:
# INFO:root:Record 2 started processing.
# INFO:root:Time taken for record 2: 8.32 seconds
# INFO:root:Record 4 started processing.
# INFO:root:Time taken for record 4: 6.81 seconds
# INFO:root:Record 5 started processing.
# INFO:root:Time taken for record 5: 6.23 seconds
# INFO:root:Record 7 started processing.
# INFO:root:Time taken for record 7: 6.10 seconds
# INFO:root:Record 8 started processing.
# INFO:root:Time taken for record 8: 4.97 seconds
# INFO:root:Record 9 started processing.
# INFO:root:Time taken for record 9: 80.87 seconds
# INFO:root:Record 10 started processing.
# INFO:root:Time taken for record 10: 10.46 seconds
# INFO:root:Record 12 started processing.
# INFO:root:Time taken for record 12: 6.07 seconds
# INFO:root:Record 13 started processing.
# INFO:root:Time taken for record 13: 5.45 seconds
# INFO:root:Total time taken: 136.56 seconds
# 136.78128862380981

# %%
col=tc1.initialize_collection(path)

# %%
hits, records, times, intervals=tc1.load_data(col)

# %%
start=time.time()
b=tc1.process_records(hits=hits, records=records, ignore_records=False, trigger_threshhold=7, times=times, n_workers=8)
print(time.time()-start)
# Out:
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# INFO:root:Record 12 started processing.
# INFO:root:Record 9 started processing.
# INFO:root:Record 3 started processing.
# INFO:root:Record 7 started processing.
# INFO:root:Record 10 started processing.
# INFO:root:Record 13 started processing.
# INFO:root:Record 11 started processing.
# INFO:root:Record 6 started processing.
# INFO:root:Time taken for record 7: 5.07 seconds
# [Parallel(n_jobs=8)]: Done   1 tasks      | elapsed:    8.2s
# INFO:root:Record 14 started processing.
# INFO:root:Time taken for record 10: 5.31 seconds
# [Parallel(n_jobs=8)]: Done   2 tasks      | elapsed:    8.6s
# INFO:root:Record 16 started processing.
# INFO:root:Time taken for record 3: 5.73 seconds
# [Parallel(n_jobs=8)]: Done   3 tasks      | elapsed:    8.9s
# INFO:root:Record 17 started processing.
# INFO:root:Time taken for record 9: 6.59 seconds
# [Parallel(n_jobs=8)]: Done   4 tasks      | elapsed:    9.8s
# ...

# %%
re
