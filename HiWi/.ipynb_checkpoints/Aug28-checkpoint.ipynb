# %%
with open('/u/arego/files_viper.txt') as f:
    lines = f.readlines()
    lines=[int(line.split('.')[0]) for line in lines]

# %%
with open('/u/arego/files.txt') as f:
    lines_rav = f.readlines()
    lines_rav=[int(line.split('.')[0]) for line in lines_rav]

# %%
len(lines_rav)
# Out:
# 23397

# %%
import numpy as np

# %%
lines=np.array(lines+lines_rav)

# %%
values= np.unique(lines, return_counts=True)

# %%
files=values[0][values[1]==2]

# %%
import os
path='/ptmp/arego/LargeTracks/'
for file in files:
    file_path=f'{path}/{file}.h5'
    if os.path.isfile(file_path):
        os.remove(file_path)

# %%
values[1].max()
# Out:
# 1

# %%
20_000*20
# Out:
# 400000

# %%
import tempfile

# %%
tempfile.gettempprefix()
# Out:
# 'tmp'

# %%
import os
import matplotlib.pyplot as plt

def plot_file_sizes(dir_path):
    files = [os.path.join(dir_path, f) for f in os.listdir(dir_path) if os.path.isfile(os.path.join(dir_path, f))]
    sizes = [os.path.getsize(f) / (1024*1024*1024) for f in files]  # MB
    plt.hist(sizes, bins=100, edgecolor='black')
    plt.xlabel("File Size (GB)")
    plt.ylabel("Count")
    plt.title(f"File Size Distribution in {dir_path}")
    plt.yscale('log')
    plt.show()

# %%
plot_file_sizes('/ptmp/arego/LargeTracks/')

# %%
dir_path='/ptmp/arego/LargeTracks/'
files = [os.path.join(dir_path, f) for f in os.listdir(dir_path) if os.path.isfile(os.path.join(dir_path, f))]
sizes = [os.path.getsize(f) / (1024*1024) for f in files]

# %%
import pandas as pd

# %%
df_dict={"file":files,
        'size':sizes}

# %%
df=pd.DataFrame(df_dict)

# %%
df=df.sort_values('size',ascending=False)

# %%
display(df[:4]['size'].sum())
# Out:
# 11743.369985580444

# %%
df['file']
# Out:
# 6704      /ptmp/arego/LargeTracks/9798.h5
# 13060     /ptmp/arego/LargeTracks/5435.h5
# 8858      /ptmp/arego/LargeTracks/8893.h5
# 16397     /ptmp/arego/LargeTracks/8556.h5
# 15596     /ptmp/arego/LargeTracks/1583.h5
#                        ...
# 7491      /ptmp/arego/LargeTracks/1196.h5
# 18485    /ptmp/arego/LargeTracks/15482.h5
# 5441      /ptmp/arego/LargeTracks/7832.h5
# 20729    /ptmp/arego/LargeTracks/17555.h5
# 17467    /ptmp/arego/LargeTracks/18826.h5
# Name: file, Length: 23293, dtype: object

# %%
22842-23293
# Out:
# -451

# %%
process_file('/ptmp/arego/LargeTracks/9798.h5')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 process_file('/ptmp/arego/LargeTracks/9798.h5')
#
# Cell In[49], line 17, in process_file(file_path, chunk_size)
#      13 try:
#      14     store_iter = pd.read_hdf(file_path, key='hits', columns=['record_id', 'time'],
#      15                              chunksize=chunk_size, iterator=True)
# ---> 17     for df in store_iter:
#      18         df["time"] = df["time"].astype("float32")
#      19         grouped = df.groupby("record_id")["time"].agg(["min", "max"])
#
# File /raven/u/arego/olympus/lib/python3.10/site-packages/pandas/io/pytables.py:1909, in TableIterator.__iter__(self)
#    1907 while current < self.stop:
#    1908     stop = min(current + self.chunksize, self.stop)
# -> 1909     value = self.func(None, None, self.coordinates[current:stop])
#    1910     current = stop
#    1911     if value is None or not len(value):
#
# File /raven/u/arego/olympus/lib/python3.10/site-packages/pandas/io/pytables.py:859, in HDFStore.select.<locals>.func(_start, _stop, _where)
#     858 def func(_start, _stop, _where):
# --> 859     return s.read(start=_start, stop=_stop, where=_where, columns=columns)
#
# File /raven/u/arego/olympus/lib/python3.10/site-packages/pandas/io/pytables.py:4537, in AppendableFrameTable.read(self, where, columns, start, stop)
#    4534 if not self.infer_axes():
#    4535     return None
# -> 4537 result = self._read_axes(where=where, start=start, stop=stop)
#    4539 info = (
#    4540     self.info.get(self.non_index_axes[0][0], {})
#    4541     if len(self.non_index_axes)
#    4542     else {}
#    4543 )
#    4545 inds = [i for i, ax in enumerate(self.axes) if ax is self.index_axes[0]]
#
# File /raven/u/arego/olympus/lib/python3.10/site-packages/pandas/io/pytables.py:3729, in Table._read_axes(self, where, start, stop)
#    3727 # create the selection
#    3728 selection = Selection(self, where=where, start=start, stop=stop)
# -> 3729 values = selection.select()
#    3731 results = []
#    3732 # convert the data
#
# File /raven/u/arego/olympus/lib/python3.10/site-packages/pandas/io/pytables.py:5275, in Selection.select(self)
#    5271     return self.table.table.read_where(
#    5272         self.condition.format(), start=self.start, stop=self.stop
#    5273     )
#    5274 elif self.coordinates is not None:
# -> 5275     return self.table.table.read_coordinates(self.coordinates)
#    5276 return self.table.table.read(start=self.start, stop=self.stop)
#
# File /raven/u/arego/olympus/lib/python3.10/site-packages/tables/table.py:1950, in Table.read_coordinates(self, coords, field)
#    1938 """Get a set of rows given their indexes as a (record) array.
#    1939
#    1940 This method works much like the :meth:`Table.read` method, but it uses
#    (...)
#    1946
#    1947 """
#    1949 self._g_check_open()
# -> 1950 result = self._read_coordinates(coords, field)
#    1951 return internal_to_flavor(result, self.flavor)
#
# File /raven/u/arego/olympus/lib/python3.10/site-packages/tables/table.py:1926, in Table._read_coordinates(self, coords, field)
#    1920     if not (isinstance(coords, np.ndarray) and
#    1921             coords.dtype.type is _npsizetype and
#    1922             coords.flags.contiguous and
#    1923             coords.flags.aligned):
#    1924         # Get a contiguous and aligned coordinate array
#    1925         coords = np.array(coords, dtype=SizeType)
# -> 1926     self._read_elements(coords, result)
#    1928 # Do the final conversions, if needed
#    1929 if field:
#
# KeyboardInterrupt:

# %%
import tables

# %%
import os
import gc
import pandas as pd


def process_file(file_path: str, chunk_size: int = 100000):
    """Process a single HDF5 file in chunks using read_hdf and compute durations for each record_id."""
    file_id = int(os.path.basename(file_path).split('.')[0])
    results = {}
    record_min = {}
    record_max = {}

    try:
        store_iter = pd.read_hdf(file_path, key='hits', columns=['record_id', 'time'],
                                 chunksize=chunk_size, iterator=True)

        for df in store_iter:
            df["time"] = df["time"].astype("float32")
            grouped = df.groupby("record_id")["time"].agg(["min", "max"])

            for rid, row in grouped.iterrows():
                if rid not in record_min or row["min"] < record_min[rid]:
                    record_min[rid] = row["min"]
                if rid not in record_max or row["max"] > record_max[rid]:
                    record_max[rid] = row["max"]
            print('1 loop ')
            break
                    

        for rid in record_min:
            duration = record_max[rid] - record_min[rid]
            modified_id = (file_id * 10**9) + int(rid)
            results[modified_id] = float(duration)

    except Exception as e:
        print(f"Error processing {file_path}: {e}")
    finally:
        gc.collect()

    return results
