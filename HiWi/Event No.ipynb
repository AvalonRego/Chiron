# %%
import pandas as pd
import numpy as np

# %%
path='/ptmp/arego/StatsEN_RedT/out.parquet'
Stats=pd.read_parquet(path)

# %%
os.listdir('/ptmp/arego')

# %%
path='/ptmp/arego/Record_Len_RedT_1/out.parquet'
RedT=pd.read_parquet(path)

# %%
RedT

# %%
path='/ptmp/arego/Record_Len_Tracks/out.parquet'
Track=pd.read_parquet(path)

# %%
temp[temp['energy']>10**4.8]

# %%
pd.read_hdf('0.h5',key="hits")

# %%
pd.read_hdf('0_pt.h5',key="records")

# %%
df=pd.read_csv('Track_skiplist.csv')

# %%
df[df.file_id==0]

# %%
skip_files, skip_records=noiseless.load_skip_records_csv('Track_skiplist.csv')

# %%
noiseless.process_and_save_hdf5('/ptmp/arego/LargeTracks/0.h5',100,)
