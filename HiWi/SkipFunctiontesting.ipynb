# %%
import pandas as pd

# %%
df=pd.read_csv('Cascade_skiplist.csv')

# %%
def skip_files(df):
    result=df.file_id.value_counts()
    return result

# %%
skip_files(df)
# Out:
# 35211    19
# 24279    18
# 35910    18
# 17661    18
# 10187    18
#          ..
# 3511      3
# 35780     3
# 30610     2
# 8090      2
# 18586     2
# Name: file_id, Length: 35364, dtype: int64

# %%
df
# Out:
#         file_id  record_id
# 0             0          0
# 1             0          4
# 2             0          5
# 3             0          7
# 4             0          9
# ...         ...        ...
# 370373    36247         21
# 370374    36247         26
# 370375    36247         29
# 370376    36247         30
# 370377    36247         32
#
# [370378 rows x 2 columns]
