# %%
import time
path1="/ptmp/arego/MIX/records/"
path2="/ptmp/arego/MIX/hits/"

# %%
t=time.time()
N=len(os.listdir(path1))
for i in range(10):
    t1=time.time()
    hits=pd.read_parquet(f'{path2}hits_{i}.parquet')
    records=pd.read_parquet(f'{path1}records_{i}.parquet')
    print(hits.index.unique().sort_values().equals(records.index.unique().sort_values()))
